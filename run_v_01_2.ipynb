# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import math
import time
import inspect
from dataclasses import dataclass
import torch
import torch.nn as nn
from torch.nn import functional as F
from transformers import AutoTokenizer

# %%
data_root = "/content/drive/MyDrive/nano_gpt" # a path for input, log and output files
poems_file_name = "first.txt"
cls_token = '[CLS]'
bob_token = '[BOB]'
bom_token = '[BOM]'
eos_token = '[EOS]'
def load_and_tokenize():
    all_files = [os.path.join(data_root, f) for f in os.listdir(data_root + "/input") if f.endswith('.txt')]
    aggregated_text = ''
    for file in all_files:

        with open(file, 'r', encoding='utf-8') as f:
            text = f.readlines()[2:] # TODO
            is_beit = True
            poem_str = f'\n{cls_token}'

            for line in text:
                if line.strip() == '':
                    continue
                poem_str += f"{bob_token + bom_token if is_beit else bom_token}{line}"
                is_beit = not is_beit
        poem_str += f'{eos_token}'

        aggregated_text += poem_str.strip()

    output_file_path = data_root + "/" + poems_file_name # Set the path for the output file
    with open(output_file_path, 'w', encoding='utf-8') as output_file:
        output_file.write(aggregated_text)

    return aggregated_text

# %%
class CausalSelfAttention(nn.Module): # Implements self-attention mechanism

    def __init__(self, config):
        super().__init__()
        assert config.n_embd % config.n_head == 0
        # key, query, value projections for all heads, but in a batch
        self.c_attn = nn.Linear(config.n_embd, 3 * config.n_embd)
        # output projection
        self.c_proj = nn.Linear(config.n_embd, config.n_embd)
        self.c_proj.NANOGPT_SCALE_INIT = 1 # standard deviation grows inside the residual stream. This line controls it.
        # regularization
        self.n_head = config.n_head
        self.n_embd = config.n_embd

    def forward(self, x):
        B, T, C = x.size() # batch size, sequence length, embedding dimensionality (n_embd)
        # calculate query, key, values for all heads in batch and move head forward to be the batch dim
        # nh is "number of heads", hs is "head size", and C (number of channels) = nh * hs
        # e.g. in GPT-2 (124M), n_head=12, hs=64, so nh*hs=C=768 channels in the Transformer
        qkv = self.c_attn(x)
        q, k, v = qkv.split(self.n_embd, dim=2)
        k = k.view(B, T, self.n_head, C // self.n_head).transpose(1, 2) # (B, nh, T, hs)
        q = q.view(B, T, self.n_head, C // self.n_head).transpose(1, 2) # (B, nh, T, hs)
        v = v.view(B, T, self.n_head, C // self.n_head).transpose(1, 2) # (B, nh, T, hs)
        y = F.scaled_dot_product_attention(q, k, v, is_causal=True) # flash attention
        y = y.transpose(1, 2).contiguous().view(B, T, C) # re-assemble all head outputs side by side
        # output projection
        y = self.c_proj(y)
        return y

class MLP(nn.Module):

    def __init__(self, config):
        super().__init__()
        self.c_fc    = nn.Linear(config.n_embd, 4 * config.n_embd)
        self.gelu    = nn.GELU(approximate='tanh')
        self.c_proj  = nn.Linear(4 * config.n_embd, config.n_embd)
        self.c_proj.NANOGPT_SCALE_INIT = 1

    def forward(self, x):
        x = self.c_fc(x)
        x = self.gelu(x)
        x = self.c_proj(x)
        return x

class Block(nn.Module):

    def __init__(self, config):
        super().__init__()
        self.ln_1 = nn.LayerNorm(config.n_embd)
        self.attn = CausalSelfAttention(config)
        self.ln_2 = nn.LayerNorm(config.n_embd)
        self.mlp = MLP(config)

    def forward(self, x):
        x = x + self.attn(self.ln_1(x)) # self.ln_1(x) noramlization --> attention think about all tokens together. aggregated function
        x = x + self.mlp(self.ln_2(x)) # self.ln_2(x) --> multi linear perc(?) # think individually about tokens
        return x

@dataclass
class GPTConfig:
    block_size: int = 1024 # max sequence length
    vocab_size: int =  25048 # tokenizer.vocab_size number of tokens: 50,000 BPE merges + 256 bytes tokens + 1 <|endoftext|> token
    n_layer: int = 6 # number of layers
    n_head: int = 6 # number of heads
    n_embd: int = 384 # embedding dimension

class GPT(nn.Module):

    def __init__(self, config):
        super().__init__()
        self.config = config

        self.transformer = nn.ModuleDict(dict(
            wte = nn.Embedding(config.vocab_size, config.n_embd), # token encoding the first box of the picture
            wpe = nn.Embedding(config.block_size, config.n_embd), # position encoding
            h = nn.ModuleList([Block(config) for _ in range(config.n_layer)]), # total block in the picture of attention is all you need
            ln_f = nn.LayerNorm(config.n_embd), # linear part of picture
        ))
        self.lm_head = nn.Linear(config.n_embd, config.vocab_size, bias=False)

        # weight sharing scheme
        self.transformer.wte.weight = self.lm_head.weight

        # init params
        self.apply(self._init_weights)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):# if a layer is linear use normal distribution std is different
            std = 0.02
            if hasattr(module, 'NANOGPT_SCALE_INIT'):
                std *= (2 * self.config.n_layer) ** -0.5
            torch.nn.init.normal_(module.weight, mean=0.0, std=std)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)

    def forward(self, idx, targets=None):
        # idx is of shape (B, T)
        B, T = idx.size()
        assert T <= self.config.block_size, f"Cannot forward sequence of length {T}, block size is only {self.config.block_size}"
        # forward the token and posisition embeddings
        pos = torch.arange(0, T, dtype=torch.long, device=idx.device) # shape (T)
        pos_emb = self.transformer.wpe(pos) # position embeddings of shape (T, n_embd)
        tok_emb = self.transformer.wte(idx) # token embeddings of shape (B, T, n_embd)
        x = tok_emb + pos_emb
        # forward the blocks of the transformer
        for block in self.transformer.h:
            x = block(x)
        # forward the final layernorm and the classifier
        x = self.transformer.ln_f(x)
        logits = self.lm_head(x) # (B, T, vocab_size)
        loss = None
        if targets is not None: # if we have target in data we calculate loss as follows
            loss = F.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1)) # flatten data by targets.view(-1)
        return logits, loss

    @classmethod
    def from_pretrained(cls, model_type): # loading wieghts. this is a constructor or class method
        """Loads pretrained GPT-2 model weights from huggingface"""
        assert model_type in {'gpt2', 'gpt2-medium', 'gpt2-large', 'gpt2-xl'}
        from transformers import GPT2LMHeadModel
        print("loading weights from pretrained gpt: %s" % model_type)

        # n_layer, n_head and n_embd are determined from model_type
        config_args = {
            'gpt2':         dict(n_layer=12, n_head=12, n_embd=768),  # 124M params
            'gpt2-medium':  dict(n_layer=24, n_head=16, n_embd=1024), # 350M params
            'gpt2-large':   dict(n_layer=36, n_head=20, n_embd=1280), # 774M params
            'gpt2-xl':      dict(n_layer=48, n_head=25, n_embd=1600), # 1558M params
        }[model_type]
        config_args['vocab_size'] = 50257 # always 50257 for GPT model checkpoints
        config_args['block_size'] = 1024 # always 1024 for GPT model checkpoints
        # create a from-scratch initialized minGPT model
        config = GPTConfig(**config_args)
        model = GPT(config)
        sd = model.state_dict()
        sd_keys = sd.keys()
        sd_keys = [k for k in sd_keys if not k.endswith('.attn.bias')] # discard this mask / buffer, not a param

        # init a huggingface/transformers model
        model_hf = GPT2LMHeadModel.from_pretrained(model_type)
        sd_hf = model_hf.state_dict()

        # copy while ensuring all of the parameters are aligned and match in names and shapes
        sd_keys_hf = sd_hf.keys()
        sd_keys_hf = [k for k in sd_keys_hf if not k.endswith('.attn.masked_bias')] # ignore these, just a buffer
        sd_keys_hf = [k for k in sd_keys_hf if not k.endswith('.attn.bias')] # same, just the mask (buffer)
        transposed = ['attn.c_attn.weight', 'attn.c_proj.weight', 'mlp.c_fc.weight', 'mlp.c_proj.weight']
        # basically the openai checkpoints use a "Conv1D" module, but we only want to use a vanilla Linear
        # this means that we have to transpose these weights when we import them
        assert len(sd_keys_hf) == len(sd_keys), f"mismatched keys: {len(sd_keys_hf)} != {len(sd_keys)}"
        for k in sd_keys_hf:
            if any(k.endswith(w) for w in transposed):
                # special treatment for the Conv1D weights we need to transpose
                assert sd_hf[k].shape[::-1] == sd[k].shape
                with torch.no_grad():
                    sd[k].copy_(sd_hf[k].t())
            else:
                # vanilla copy over the other parameters
                assert sd_hf[k].shape == sd[k].shape
                with torch.no_grad():
                    sd[k].copy_(sd_hf[k])

        return model

    def configure_optimizers(self, weight_decay, learning_rate, device_type):
        # start with all of the candidate parameters (that require grad)
        param_dict = {pn: p for pn, p in self.named_parameters()}
        param_dict = {pn: p for pn, p in param_dict.items() if p.requires_grad}
        # create optim groups. Any parameters that is 2D will be weight decayed, otherwise no.
        # i.e. all weight tensors in matmuls + embeddings decay, all biases and layernorms don't.
        decay_params = [p for n, p in param_dict.items() if p.dim() >= 2]
        nodecay_params = [p for n, p in param_dict.items() if p.dim() < 2]
        optim_groups = [
            {'params': decay_params, 'weight_decay': weight_decay},
            {'params': nodecay_params, 'weight_decay': 0.0}
        ]
        num_decay_params = sum(p.numel() for p in decay_params)
        num_nodecay_params = sum(p.numel() for p in nodecay_params)
        if master_process:
            print(f"num decayed parameter tensors: {len(decay_params)}, with {num_decay_params:,} parameters")
            print(f"num non-decayed parameter tensors: {len(nodecay_params)}, with {num_nodecay_params:,} parameters")
        # Create AdamW optimizer and use the fused version if it is available
        fused_available = 'fused' in inspect.signature(torch.optim.AdamW).parameters
        use_fused = fused_available and device_type == "cuda"
        if master_process:
            print(f"using fused AdamW: {use_fused}")
        optimizer = torch.optim.AdamW(optim_groups, lr=learning_rate, betas=(0.9, 0.95), eps=1e-8, fused=use_fused)
        return optimizer

# %%
tokenizer = AutoTokenizer.from_pretrained('bolbolzaban/gpt2-persian')
special_tokens = {"cls_token": "[CLS]", "additional_special_tokens":["[BOM]","[BOB]","[SEP]","<unk>"],"eos_token":"[EOS]"}
tokenizer.add_special_tokens(special_tokens)
tokenizer.cls_token = "[CLS]"
tokenizer.bob_token ="[BOB]"
tokenizer.bom_token = "[BOM]"
tokenizer.eos_token ="[EOS]"
enc = tokenizer

# %%
# test
cls_token = '[CLS]'
bob_token = '[BOB]'
bom_token = '[BOM]'
eos_token = '[EOS]'
def load_and_tokenize(filename):
    with open(filename, 'r', encoding='utf-8') as f:
        text = f.readlines()
        is_beit = True
        poem_str = f'\n{cls_token}'
        # print(text)
        for index , line in enumerate(text):
            if line.strip() == '':
                continue
            poem_str += f"{bob_token + bom_token if is_beit else bom_token}{line}"
            is_beit = not is_beit
    poem_str += f'{eos_token}'
    # print(poem_str)
    text = poem_str.strip()
    print("print something")
    return text

print(load_and_tokenize(data_root + '/input/2nd.txt'))
# load_and_tokenize(data_root + '/input/aggregated_poems.txt')
# Out:
# print something
# [CLS][BOB][BOM]الا يا ايها الساقی ادر کاسا و ناولها
# [BOM]که عشق آسان نمود اول ولی افتاد مشکل‌ها
# [BOB][BOM]به بوی نافه‌ای کاخر صبا زان طره بگشايد
# [BOM]ز تاب جعد مشکينش چه خون افتاد در دل‌ها
# [BOB][BOM]مرا در منزل جانان چه امن عيش چون هر دم
# [BOM]جرس فرياد می‌دارد که بربنديد محمل‌ها
# [BOB][BOM]به می سجاده رنگين کن گرت پير مغان گويد
# [BOM]که سالک بی‌خبر نبود ز راه و رسم منزل‌ها
# [BOB][BOM]شب تاريک و بيم موج و گردابی چنين هايل
# [BOM]کجا دانند حال ما سبکباران ساحل‌ها
# [BOB][BOM]همه کارم ز خود کامی به بدنامی کشيد آخر
# [BOM]نهان کی ماند آن رازی کز او سازند محفل‌ها
# [BOB][BOM]حضوری گر همی‌خواهی از او غايب مشو حافظ
# [BOM]متی ما تلق من تهوی دع الدنيا و اهملها
# [BOB][BOM]صلاح کار کجا و من خراب کجا
# [BOM]ببين تفاوت ره کز کجاست تا به کجا
# [BOB][BOM]دلم ز صومعه بگرفت و خرقه سالوس
# [BOM]کجاست دير مغان و شراب ناب کجا
# [BOB][BOM]چه نسبت است به رندی صلاح و تقوا را
# [BOM]سماع وعظ کجا نغمه رباب کجا
# [BOB][BOM]ز روی دوست دل دشمنان چه دريابد
# [BOM]چراغ مرده کجا شمع آفتاب کجا
# [BOB][BOM]چو کحل بينش ما خاک آستان شماست
# [BOM]کجا رويم بفرما از اين جناب کجا
# [BOB][BOM]مبين به سيب زنخدان که چاه در راه است
# [BOM]کجا همی‌روی ای دل بدين شتاب کجا
# [BOB][BOM]بشد که ياد خوشش باد روزگار وصال
# [BOM]خود آن کرشمه کجا رفت و آن عتاب کجا
# [BOB][BOM]قرار و خواب ز حافظ طمع مدار ای دوست
# [BOM]قرار چيست صبوری کدام و خواب کجا
# [BOB][BOM]اگر آن ترک شيرازی به دست آرد دل ما را
# [BOM]به خال هندويش بخشم سمرقند و بخارا را
# [BOB][BOM]بده ساقی می باقی که در جنت نخواهی يافت
# [BOM]کنار آب رکن آباد و گلگشت مصلا را
# [BOB][BOM]فغان کاين لوليان شوخ شيرين کار شهرآشوب
# [BOM]چنان بردند صبر از دل که ترکان خوان يغما را
# [BOB][BOM]ز عشق ناتمام ما جمال يار مستغنی است
# [BOM]به آب و رنگ و خال و خط چه حاجت روی زيبا را
# [BOB][BOM]من از آن حسن روزافزون که يوسف داشت دانستم
# [BOM]که عشق از پرده عصمت برون آرد زليخا را
# [BOB][BOM]اگر دشنام فرمايی و گر نفرين دعا گويم
# [BOM]جواب تلخ می‌زيبد لب لعل شکرخا را
# [BOB][BOM]نصيحت گوش کن جانا که از جان دوست‌تر دارند
# [BOM]جوانان سعادتمند پند پير دانا را
# [BOB][BOM]حديث از مطرب و می گو و راز دهر کمتر جو
# [BOM]که کس نگشود و نگشايد به حکمت اين معما را
# [BOB][BOM]غزل گفتی و در سفتی بيا و خوش بخوان حافظ
# [BOM]که بر نظم تو افشاند فلک عقد ثريا را
# [BOB][BOM]صبا به لطف بگو آن غزال رعنا را
# [BOM]که سر به کوه و بيابان تو داده‌ای ما را
# [BOB][BOM]شکرفروش که عمرش دراز باد چرا
# [BOM]تفقدی نکند طوطی شکرخا را
# [BOB][BOM]غرور حسنت اجازت مگر نداد ای گل
# [BOM]که پرسشی نکنی عندليب شيدا را
# [BOB][BOM]به خلق و لطف توان کرد صيد اهل نظر
# [BOM]به بند و دام نگيرند مرغ دانا را
# [BOB][BOM]ندانم از چه سبب رنگ آشنايی نيست
# [BOM]سهی قدان سيه چشم ماه سيما را
# [BOB][BOM]چو با حبيب نشينی و باده پيمايی
# [BOM]به ياد دار محبان بادپيما را
# [BOB][BOM]جز اين قدر نتوان گفت در جمال تو عيب
# [BOM]که وضع مهر و وفا نيست روی زيبا را
# [BOB][BOM]در آسمان نه عجب گر به گفته حافظ
# [BOM]سرود زهره به رقص آورد مسيحا را
# [BOB][BOM]دل می‌رود ز دستم صاحب دلان خدا را
# [BOM]دردا که راز پنهان خواهد شد آشکارا
# [BOB][BOM]کشتی شکستگانيم ای باد شرطه برخيز
# [BOM]باشد که بازبينيم ديدار آشنا را
# [BOB][BOM]ده روزه مهر گردون افسانه است و افسون
# [BOM]نيکی به جای ياران فرصت شمار يارا
# [BOB][BOM]در حلقه گل و مل خوش خواند دوش بلبل
# [BOM]هات الصبوح هبوا يا ايها السکارا
# [BOB][BOM]ای صاحب کرامت شکرانه سلامت
# [BOM]روزی تفقدی کن درويش بی‌نوا را
# [BOB][BOM]آسايش دو گيتی تفسير اين دو حرف است
# [BOM]با دوستان مروت با دشمنان مدارا
# [BOB][BOM]در کوی نيک نامی ما را گذر ندادند
# [BOM]گر تو نمی‌پسندی تغيير کن قضا را
# [BOB][BOM]آن تلخ وش که صوفی ام الخباثش خواند
# [BOM]اشهی لنا و احلی من قبله العذارا
# [BOB][BOM]هنگام تنگدستی در عيش کوش و مستی
# [BOM]کاين کيميای هستی قارون کند گدا را
# [BOB][BOM]سرکش مشو که چون شمع از غيرتت بسوزد
# [BOM]دلبر که در کف او موم است سنگ خارا
# [BOB][BOM]آيينه سکندر جام می است بنگر
# [BOM]تا بر تو عرضه دارد احوال ملک دارا
# [BOB][BOM]خوبان پارسی گو بخشندگان عمرند
# [BOM]ساقی بده بشارت رندان پارسا را
# [BOB][BOM]حافظ به خود نپوشيد اين خرقه می آلود
# [BOM]ای شيخ پاکدامن معذور دار ما را
# [BOB][BOM]به ملازمان سلطان که رساند اين دعا را
# [BOM]که به شکر پادشاهی ز نظر مران گدا را
# [BOB][BOM]ز رقيب ديوسيرت به خدای خود پناهم
# [BOM]مگر آن شهاب ثاقب مددی دهد خدا را
# [BOB][BOM]مژه سياهت ار کرد به خون ما اشارت
# [BOM]ز فريب او بينديش و غلط مکن نگارا
# [BOB][BOM]دل عالمی بسوزی چو عذار برفروزی
# [BOM]تو از اين چه سود داری که نمی‌کنی مدارا
# [BOB][BOM]همه شب در اين اميدم که نسيم صبحگاهی
# [BOM]به پيام آشنايان بنوازد آشنا را
# [BOB][BOM]چه قيامت است جانا که به عاشقان نمودی
# [BOM]دل و جان فدای رويت بنما عذار ما را
# [BOB][BOM]به خدا که جرعه‌ای ده تو به حافظ سحرخيز
# [BOM]که دعای صبحگاهی اثری کند شما را
# [BOB][BOM]صوفی بيا که آينه صافيست جام را
# [BOM]تا بنگری صفای می لعل فام را
# [BOB][BOM]راز درون پرده ز رندان مست پرس
# [BOM]کاين حال نيست زاهد عالی مقام را
# [BOB][BOM]عنقا شکار کس نشود دام بازچين
# [BOM]کان جا هميشه باد به دست است دام را
# [BOB][BOM]در بزم دور يک دو قدح درکش و برو
# [BOM]يعنی طمع مدار وصال دوام را
# [BOB][BOM]ای دل شباب رفت و نچيدی گلی ز عيش
# [BOM]پيرانه سر مکن هنری ننگ و نام را
# [BOB][BOM]در عيش نقد کوش که چون آبخور نماند
# [BOM]آدم بهشت روضه دارالسلام را
# [BOB][BOM]ما را بر آستان تو بس حق خدمت است
# [BOM]ای خواجه بازبين به ترحم غلام را
# [BOB][BOM]حافظ مريد جام می است ای صبا برو
# [BOM]وز بنده بندگی برسان شيخ جام را
# [BOB][BOM]ساقيا برخيز و درده جام را
# [BOM]خاک بر سر کن غم ايام را
# [BOB][BOM]ساغر می بر کفم نه تا ز بر
# [BOM]برکشم اين دلق ازرق فام را
# [BOB][BOM]گر چه بدناميست نزد عاقلان
# [BOM]ما نمی‌خواهيم ننگ و نام را
# [BOB][BOM]باده درده چند از اين باد غرور
# [BOM]خاک بر سر نفس نافرجام را
# [BOB][BOM]دود آه سينه نالان من
# [BOM]سوخت اين افسردگان خام را
# [BOB][BOM]محرم راز دل شيدای خود
# [BOM]کس نمی‌بينم ز خاص و عام را
# [BOB][BOM]با دلارامی مرا خاطر خوش است
# [BOM]کز دلم يک باره برد آرام را
# [BOB][BOM]ننگرد ديگر به سرو اندر چمن
# [BOM]هر که ديد آن سرو سيم اندام را
# [BOB][BOM]صبر کن حافظ به سختی روز و شب
# [BOM]عاقبت روزی بيابی کام را
# [BOB][BOM]رونق عهد شباب است دگر بستان را
# [BOM]می‌رسد مژده گل بلبل خوش الحان را
# [BOB][BOM]ای صبا گر به جوانان چمن بازرسی
# [BOM]خدمت ما برسان سرو و گل و ريحان را
# [BOB][BOM]گر چنين جلوه کند مغبچه باده فروش
# [BOM]خاکروب در ميخانه کنم مژگان را
# [BOB][BOM]ای که بر مه کشی از عنبر سارا چوگان
# [BOM]مضطرب حال مگردان من سرگردان را
# [BOB][BOM]ترسم اين قوم که بر دردکشان می‌خندند
# [BOM]در سر کار خرابات کنند ايمان را
# [BOB][BOM]يار مردان خدا باش که در کشتی نوح
# [BOM]هست خاکی که به آبی نخرد طوفان را
# [BOB][BOM]برو از خانه گردون به در و نان مطلب
# [BOM]کان سيه کاسه در آخر بکشد مهمان را
# [BOB][BOM]هر که را خوابگه آخر مشتی خاک است
# [BOM]گو چه حاجت که به افلاک کشی ايوان را
# [BOB][BOM]ماه کنعانی من مسند مصر آن تو شد
# [BOM]وقت آن است که بدرود کنی زندان را
# [BOB][BOM]حافظا می خور و رندی کن و خوش باش ولی
# [BOM]دام تزوير مکن چون دگران قرآن را
# [BOB][BOM]دوش از مسجد سوی ميخانه آمد پير ما
# [BOM]چيست ياران طريقت بعد از اين تدبير ما
# [BOB][BOM]ما مريدان روی سوی قبله چون آريم چون
# [BOM]روی سوی خانه خمار دارد پير ما
# [BOB][BOM]در خرابات طريقت ما به هم منزل شويم
# [BOM]کاين چنين رفته‌ست در عهد ازل تقدير ما
# [BOB][BOM]عقل اگر داند که دل دربند زلفش چون خوش است
# [BOM]عاقلان ديوانه گردند از پی زنجير ما
# [BOB][BOM]روی خوبت آيتی از لطف بر ما کشف کرد
# [BOM]زان زمان جز لطف و خوبی نيست در تفسير ما
# [BOB][BOM]با دل سنگينت آيا هيچ درگيرد شبی
# [BOM]آه آتشناک و سوز سينه شبگير ما
# [BOB][BOM]تير آه ما ز گردون بگذرد حافظ خموش
# [BOM]رحم کن بر جان خود پرهيز کن از تير ما
# [BOB][BOM]ساقی به نور باده برافروز جام ما
# [BOM]مطرب بگو که کار جهان شد به کام ما
# [BOB][BOM]ما در پياله عکس رخ يار ديده‌ايم
# [BOM]ای بی‌خبر ز لذت شرب مدام ما
# [BOB][BOM]هرگز نميرد آن که دلش زنده شد به عشق
# [BOM]ثبت است بر جريده عالم دوام ما
# [BOB][BOM]چندان بود کرشمه و ناز سهی قدان
# [BOM]کايد به جلوه سرو صنوبرخرام ما
# [BOB][BOM]ای باد اگر به گلشن احباب بگذری
# [BOM]زنهار عرضه ده بر جانان پيام ما
# [BOB][BOM]گو نام ما ز ياد به عمدا چه می‌بری
# [BOM]خود آيد آن که ياد نياری ز نام ما
# [BOB][BOM]مستی به چشم شاهد دلبند ما خوش است
# [BOM]زان رو سپرده‌اند به مستی زمام ما
# [BOB][BOM]ترسم که صرفه‌ای نبرد روز بازخواست
# [BOM]نان حلال شيخ ز آب حرام ما
# [BOB][BOM]حافظ ز ديده دانه اشکی همی‌فشان
# [BOM]باشد که مرغ وصل کند قصد دام ما
# [BOB][BOM]دريای اخضر فلک و کشتی هلال
# [BOM]هستند غرق نعمت حاجی قوام ما
# [BOB][BOM]ای فروغ ماه حسن از روی رخشان شما
# [BOM]آب روی خوبی از چاه زنخدان شما
# [BOB][BOM]عزم ديدار تو دارد جان بر لب آمده
# [BOM]بازگردد يا برآيد چيست فرمان شما
# [BOB][BOM]کس به دور نرگست طرفی نبست از عافيت
# [BOM]به که نفروشند مستوری به مستان شما
# [BOB][BOM]بخت خواب آلود ما بيدار خواهد شد مگر
# [BOM]زان که زد بر ديده آبی روی رخشان شما
# [BOB][BOM]با صبا همراه بفرست از رخت گلدسته‌ای
# [BOM]بو که بويی بشنويم از خاک بستان شما
# [BOB][BOM]عمرتان باد و مراد ای ساقيان بزم جم
# [BOM]گر چه جام ما نشد پرمی به دوران شما
# [BOB][BOM]دل خرابی می‌کند دلدار را آگه کنيد
# [BOM]زينهار ای دوستان جان من و جان شما
# [BOB][BOM]کی دهد دست اين غرض يا رب که همدستان شوند
# [BOM]خاطر مجموع ما زلف پريشان شما
# [BOB][BOM]دور دار از خاک و خون دامن چو بر ما بگذری
# [BOM]کاندر اين ره کشته بسيارند قربان شما
# [BOB][BOM]ای صبا با ساکنان شهر يزد از ما بگو
# [BOM]کای سر حق ناشناسان گوی چوگان شما
# [BOB][BOM]گر چه دوريم از بساط قرب همت دور نيست
# [BOM]بنده شاه شماييم و ثناخوان شما
# [BOB][BOM]ای شهنشاه بلنداختر خدا را همتی
# [BOM]تا ببوسم همچو اختر خاک ايوان شما
# [BOB][BOM]می‌کند حافظ دعايی بشنو آمينی بگو
# [BOM]روزی ما باد لعل شکرافشان شما
# [BOB][BOM]می‌دمد صبح و کله بست سحاب
# [BOM]الصبوح الصبوح يا اصحاب
# [BOB][BOM]می‌چکد ژاله بر رخ لاله
# [BOM]المدام المدام يا احباب
# [BOB][BOM]می‌وزد از چمن نسيم بهشت
# [BOM]هان بنوشيد دم به دم می ناب
# [BOB][BOM]تخت زمرد زده است گل به چمن
# [BOM]راح چون لعل آتشين درياب
# [BOB][BOM]در ميخانه بسته‌اند دگر
# [BOM]افتتح يا مفتح الابواب
# [BOB][BOM]لب و دندانت را حقوق نمک
# [BOM]هست بر جان و سينه‌های کباب
# [BOB][BOM]اين چنين موسمی عجب باشد
# [BOM]که ببندند ميکده به شتاب
# [BOB][BOM]بر رخ ساقی پری پيکر
# [BOM]همچو حافظ بنوش باده ناب
# [BOB][BOM]گفتم ای سلطان خوبان رحم کن بر اين غريب
# [BOM]گفت در دنبال دل ره گم کند مسکين غريب
# [BOB][BOM]گفتمش مگذر زمانی گفت معذورم بدار
# [BOM]خانه پروردی چه تاب آرد غم چندين غريب
# [BOB][BOM]خفته بر سنجاب شاهی نازنينی را چه غم
# [BOM]گر ز خار و خاره سازد بستر و بالين غريب
# [BOB][BOM]ای که در زنجير زلفت جای چندين آشناست
# [BOM]خوش فتاد آن خال مشکين بر رخ رنگين غريب
# [BOB][BOM]می‌نمايد عکس می در رنگ روی مه وشت
# [BOM]همچو برگ ارغوان بر صفحه نسرين غريب
# [BOB][BOM]بس غريب افتاده است آن مور خط گرد رخت
# [BOM]گر چه نبود در نگارستان خط مشکين غريب
# [BOB][BOM]گفتم ای شام غريبان طره شبرنگ تو
# [BOM]در سحرگاهان حذر کن چون بنالد اين غريب
# [BOB][BOM]گفت حافظ آشنايان در مقام حيرتند
# [BOM]دور نبود گر نشيند خسته و مسکين غريب
# [BOB][BOM]ای شاهد قدسی که کشد بند نقابت
# [BOM]و ای مرغ بهشتی که دهد دانه و آبت
# [BOB][BOM]خوابم بشد از ديده در اين فکر جگرسوز
# [BOM]کاغوش که شد منزل آسايش و خوابت
# [BOB][BOM]درويش نمی‌پرسی و ترسم که نباشد
# [BOM]انديشه آمرزش و پروای ثوابت
# [BOB][BOM]راه دل عشاق زد آن چشم خماری
# [BOM]پيداست از اين شيوه که مست است شرابت
# [BOB][BOM]تيری که زدی بر دلم از غمزه خطا رفت
# [BOM]تا باز چه انديشه کند رای صوابت
# [BOB][BOM]هر ناله و فرياد که کردم نشنيدی
# [BOM]پيداست نگارا که بلند است جنابت
# [BOB][BOM]دور است سر آب از اين باديه هش دار
# [BOM]تا غول بيابان نفريبد به سرابت
# [BOB][BOM]تا در ره پيری به چه آيين روی ای دل
# [BOM]باری به غلط صرف شد ايام شبابت
# [BOB][BOM]ای قصر دل افروز که منزلگه انسی
# [BOM]يا رب مکناد آفت ايام خرابت
# [BOB][BOM]حافظ نه غلاميست که از خواجه گريزد
# [BOM]صلحی کن و بازآ که خرابم ز عتابت
# [BOB][BOM]خمی که ابروی شوخ تو در کمان انداخت
# [BOM]به قصد جان من زار ناتوان انداخت
# [BOB][BOM]نبود نقش دو عالم که رنگ الفت بود
# [BOM]زمانه طرح محبت نه اين زمان انداخت
# [BOB][BOM]به يک کرشمه که نرگس به خودفروشی کرد
# [BOM]فريب چشم تو صد فتنه در جهان انداخت
# [BOB][BOM]شراب خورده و خوی کرده می‌روی به چمن
# [BOM]که آب روی تو آتش در ارغوان انداخت
# [BOB][BOM]به بزمگاه چمن دوش مست بگذشتم
# [BOM]چو از دهان توام غنچه در گمان انداخت
# [BOB][BOM]بنفشه طره مفتول خود گره می‌زد
# [BOM]صبا حکايت زلف تو در ميان انداخت
# [BOB][BOM]ز شرم آن که به روی تو نسبتش کردم
# [BOM]سمن به دست صبا خاک در دهان انداخت
# [BOB][BOM]من از ورع می و مطرب نديدمی زين پيش
# [BOM]هوای مغبچگانم در اين و آن انداخت
# [BOB][BOM]کنون به آب می لعل خرقه می‌شويم
# [BOM]نصيبه ازل از خود نمی‌توان انداخت
# [BOB][BOM]مگر گشايش حافظ در اين خرابی بود
# [BOM]که بخشش ازلش در می مغان انداخت
# [BOB][BOM]جهان به کام من اکنون شود که دور زمان
# [BOM]مرا به بندگی خواجه جهان انداخت
# [BOB][BOM]سينه از آتش دل در غم جانانه بسوخت
# [BOM]آتشی بود در اين خانه که کاشانه بسوخت
# [BOB][BOM]تنم از واسطه دوری دلبر بگداخت
# [BOM]جانم از آتش مهر رخ جانانه بسوخت
# [BOB][BOM]سوز دل بين که ز بس آتش اشکم دل شمع
# [BOM]دوش بر من ز سر مهر چو پروانه بسوخت
# [BOB][BOM]آشنايی نه غريب است که دلسوز من است
# [BOM]چون من از خويش برفتم دل بيگانه بسوخت
# [BOB][BOM]خرقه زهد مرا آب خرابات ببرد
# [BOM]خانه عقل مرا آتش ميخانه بسوخت
# [BOB][BOM]چون پياله دلم از توبه که کردم بشکست
# [BOM]همچو لاله جگرم بی می و خمخانه بسوخت
# [BOB][BOM]ماجرا کم کن و بازآ که مرا مردم چشم
# [BOM]خرقه از سر به درآورد و به شکرانه بسوخت
# [BOB][BOM]ترک افسانه بگو حافظ و می نوش دمی
# [BOM]که نخفتيم شب و شمع به افسانه بسوخت
# [BOB][BOM]ساقيا آمدن عيد مبارک بادت
# [BOM]وان مواعيد که کردی مرواد از يادت
# [BOB][BOM]در شگفتم که در اين مدت ايام فراق
# [BOM]برگرفتی ز حريفان دل و دل می‌دادت
# [BOB][BOM]برسان بندگی دختر رز گو به درآی
# [BOM]که دم و همت ما کرد ز بند آزادت
# [BOB][BOM]شادی مجلسيان در قدم و مقدم توست
# [BOM]جای غم باد مر آن دل که نخواهد شادت
# [BOB][BOM]شکر ايزد که ز تاراج خزان رخنه نيافت
# [BOM]بوستان سمن و سرو و گل و شمشادت
# [BOB][BOM]چشم بد دور کز آن تفرقه‌ات بازآورد
# [BOM]طالع نامور و دولت مادرزادت
# [BOB][BOM]حافظ از دست مده دولت اين کشتی نوح
# [BOM]ور نه طوفان حوادث ببرد بنيادت
# [BOB][BOM]ای نسيم سحر آرامگه يار کجاست
# [BOM]منزل آن مه عاشق کش عيار کجاست
# [BOB][BOM]شب تار است و ره وادی ايمن در پيش
# [BOM]آتش طور کجا موعد ديدار کجاست
# [BOB][BOM]هر که آمد به جهان نقش خرابی دارد
# [BOM]در خرابات بگوييد که هشيار کجاست
# [BOB][BOM]آن کس است اهل بشارت که اشارت داند
# [BOM]نکته‌ها هست بسی محرم اسرار کجاست
# [BOB][BOM]هر سر موی مرا با تو هزاران کار است
# [BOM]ما کجاييم و ملامت گر بی‌کار کجاست
# [BOB][BOM]بازپرسيد ز گيسوی شکن در شکنش
# [BOM]کاين دل غمزده سرگشته گرفتار کجاست
# [BOB][BOM]عقل ديوانه شد آن سلسله مشکين کو
# [BOM]دل ز ما گوشه گرفت ابروی دلدار کجاست
# [BOB][BOM]ساقی و مطرب و می جمله مهياست ولی
# [BOM]عيش بی يار مهيا نشود يار کجاست
# [BOB][BOM]حافظ از باد خزان در چمن دهر مرنج
# [BOM]فکر معقول بفرما گل بی خار کجاست
# [BOB][BOM]روزه يک سو شد و عيد آمد و دل‌ها برخاست
# [BOM]می ز خمخانه به جوش آمد و می بايد خواست
# [BOB][BOM]نوبه زهدفروشان گران جان بگذشت
# [BOM]وقت رندی و طرب کردن رندان پيداست
# [BOB][BOM]چه ملامت بود آن را که چنين باده خورد
# [BOM]اين چه عيب است بدين بی‌خردی وين چه خطاست
# [BOB][BOM]باده نوشی که در او روی و ريايی نبود
# [BOM]بهتر از زهدفروشی که در او روی و رياست
# [BOB][BOM]ما نه رندان رياييم و حريفان نفاق
# [BOM]آن که او عالم سر است بدين حال گواست
# [BOB][BOM]فرض ايزد بگذاريم و به کس بد نکنيم
# [BOM]وان چه گويند روا نيست نگوييم رواست
# [BOB][BOM]چه شود گر من و تو چند قدح باده خوريم
# [BOM]باده از خون رزان است نه از خون شماست
# [BOB][BOM]اين چه عيب است کز آن عيب خلل خواهد بود
# [BOM]ور بود نيز چه شد مردم بی‌عيب کجاست
# [BOB][BOM]دل و دينم شد و دلبر به ملامت برخاست
# [BOM]گفت با ما منشين کز تو سلامت برخاست
# [BOB][BOM]که شنيدی که در اين بزم دمی خوش بنشست
# [BOM]که نه در آخر صحبت به ندامت برخاست
# [BOB][BOM]شمع اگر زان لب خندان به زبان لافی زد
# [BOM]پيش عشاق تو شب‌ها به غرامت برخاست
# [BOB][BOM]در چمن باد بهاری ز کنار گل و سرو
# [BOM]به هواداری آن عارض و قامت برخاست
# [BOB][BOM]مست بگذشتی و از خلوتيان ملکوت
# [BOM]به تماشای تو آشوب قيامت برخاست
# [BOB][BOM]پيش رفتار تو پا برنگرفت از خجلت
# [BOM]سرو سرکش که به ناز از قد و قامت برخاست
# [BOB][BOM]حافظ اين خرقه بينداز مگر جان ببری
# [BOM]کاتش از خرقه سالوس و کرامت برخاست
# [BOB][BOM]چو بشنوی سخن اهل دل مگو که خطاست
# [BOM]سخن شناس نه‌ای جان من خطا اين جاست
# [BOB][BOM]سرم به دنيی و عقبی فرو نمی‌آيد
# [BOM]تبارک الله از اين فتنه‌ها که در سر ماست
# [BOB][BOM]در اندرون من خسته دل ندانم کيست
# [BOM]که من خموشم و او در فغان و در غوغاست
# [BOB][BOM]دلم ز پرده برون شد کجايی ای مطرب
# [BOM]بنال هان که از اين پرده کار ما به نواست
# [BOB][BOM]مرا به کار جهان هرگز التفات نبود
# [BOM]رخ تو در نظر من چنين خوشش آراست
# [BOB][BOM]نخفته‌ام ز خيالی که می‌پزد دل من
# [BOM]خمار صدشبه دارم شرابخانه کجاست
# [BOB][BOM]چنين که صومعه آلوده شد ز خون دلم
# [BOM]گرم به باده بشوييد حق به دست شماست
# [BOB][BOM]از آن به دير مغانم عزيز می‌دارند
# [BOM]که آتشی که نميرد هميشه در دل ماست
# [BOB][BOM]چه ساز بود که در پرده می‌زد آن مطرب
# [BOM]که رفت عمر و هنوزم دماغ پر ز هواست
# [BOB][BOM]ندای عشق تو ديشب در اندرون دادند
# [BOM]فضای سينه حافظ هنوز پر ز صداست
# [BOB][BOM]خيال روی تو در هر طريق همره ماست
# [BOM]نسيم موی تو پيوند جان آگه ماست
# [BOB][BOM]به رغم مدعيانی که منع عشق کنند
# [BOM]جمال چهره تو حجت موجه ماست
# [BOB][BOM]ببين که سيب زنخدان تو چه می‌گويد
# [BOM]هزار يوسف مصری فتاده در چه ماست
# [BOB][BOM]اگر به زلف دراز تو دست ما نرسد
# [BOM]گناه بخت پريشان و دست کوته ماست
# [BOB][BOM]به حاجب در خلوت سرای خاص بگو
# [BOM]فلان ز گوشه نشينان خاک درگه ماست
# [BOB][BOM]به صورت از نظر ما اگر چه محجوب است
# [BOM]هميشه در نظر خاطر مرفه ماست
# [BOB][BOM]اگر به سالی حافظ دری زند بگشای
# [BOM]که سال‌هاست که مشتاق روی چون مه ماست
# [BOB][BOM]مطلب طاعت و پيمان و صلاح از من مست
# [BOM]که به پيمانه کشی شهره شدم روز الست
# [BOB][BOM]من همان دم که وضو ساختم از چشمه عشق
# [BOM]چارتکبير زدم يک سره بر هر چه که هست
# [BOB][BOM]می بده تا دهمت آگهی از سر قضا
# [BOM]که به روی که شدم عاشق و از بوی که مست
# [BOB][BOM]کمر کوه کم است از کمر مور اين جا
# [BOM]نااميد از در رحمت مشو ای باده پرست
# [BOB][BOM]بجز آن نرگس مستانه که چشمش مرساد
# [BOM]زير اين طارم فيروزه کسی خوش ننشست
# [BOB][BOM]جان فدای دهنش باد که در باغ نظر
# [BOM]چمن آرای جهان خوشتر از اين غنچه نبست
# [BOB][BOM]حافظ از دولت عشق تو سليمانی شد
# [BOM]يعنی از وصل تواش نيست بجز باد به دست
# [BOB][BOM]شکفته شد گل حمرا و گشت بلبل مست
# [BOM]صلای سرخوشی ای صوفيان باده پرست
# [BOB][BOM]اساس توبه که در محکمی چو سنگ نمود
# [BOM]ببين که جام زجاجی چه طرفه‌اش بشکست
# [BOB][BOM]بيار باده که در بارگاه استغنا
# [BOM]چه پاسبان و چه سلطان چه هوشيار و چه مست
# [BOB][BOM]از اين رباط دودر چون ضرورت است رحيل
# [BOM]رواق و طاق معيشت چه سربلند و چه پست
# [BOB][BOM]مقام عيش ميسر نمی‌شود بی‌رنج
# [BOM]بلی به حکم بلا بسته‌اند عهد الست
# [BOB][BOM]به هست و نيست مرنجان ضمير و خوش می‌باش
# [BOM]که نيستيست سرانجام هر کمال که هست
# [BOB][BOM]شکوه آصفی و اسب باد و منطق طير
# [BOM]به باد رفت و از او خواجه هيچ طرف نبست
# [BOB][BOM]به بال و پر مرو از ره که تير پرتابی
# [BOM]هوا گرفت زمانی ولی به خاک نشست
# [BOB][BOM]زبان کلک تو حافظ چه شکر آن گويد
# [BOM]که گفته سخنت می‌برند دست به دست
# [BOB][BOM]زلف آشفته و خوی کرده و خندان لب و مست
# [BOM]پيرهن چاک و غزل خوان و صراحی در دست
# [BOB][BOM]نرگسش عربده جوی و لبش افسوس کنان
# [BOM]نيم شب دوش به بالين من آمد بنشست
# [BOB][BOM]سر فرا گوش من آورد به آواز حزين
# [BOM]گفت ای عاشق ديرينه من خوابت هست
# [BOB][BOM]عاشقی را که چنين باده شبگير دهند
# [BOM]کافر عشق بود گر نشود باده پرست
# [BOB][BOM]برو ای زاهد و بر دردکشان خرده مگير
# [BOM]که ندادند جز اين تحفه به ما روز الست
# [BOB][BOM]آن چه او ريخت به پيمانه ما نوشيديم
# [BOM]اگر از خمر بهشت است وگر باده مست
# [BOB][BOM]خنده جام می و زلف گره گير نگار
# [BOM]ای بسا توبه که چون توبه حافظ بشکست
# [BOB][BOM]در دير مغان آمد يارم قدحی در دست
# [BOM]مست از می و ميخواران از نرگس مستش مست
# [BOB][BOM]در نعل سمند او شکل مه نو پيدا
# [BOM]وز قد بلند او بالای صنوبر پست
# [BOB][BOM]آخر به چه گويم هست از خود خبرم چون نيست
# [BOM]وز بهر چه گويم نيست با وی نظرم چون هست
# [BOB][BOM]شمع دل دمسازم بنشست چو او برخاست
# [BOM]و افغان ز نظربازان برخاست چو او بنشست
# [BOB][BOM]گر غاليه خوش بو شد در گيسوی او پيچيد
# [BOM]ور وسمه کمانکش گشت در ابروی او پيوست
# [BOB][BOM]بازآی که بازآيد عمر شده حافظ
# [BOM]هر چند که نايد باز تيری که بشد از شست
# [BOB][BOM]به جان خواجه و حق قديم و عهد درست
# [BOM]که مونس دم صبحم دعای دولت توست
# [BOB][BOM]سرشک من که ز طوفان نوح دست برد
# [BOM]ز لوح سينه نيارست نقش مهر تو شست
# [BOB][BOM]بکن معامله‌ای وين دل شکسته بخر
# [BOM]که با شکستگی ارزد به صد هزار درست
# [BOB][BOM]زبان مور به آصف دراز گشت و رواست
# [BOM]که خواجه خاتم جم ياوه کرد و بازنجست
# [BOB][BOM]دلا طمع مبر از لطف بی‌نهايت دوست
# [BOM]چو لاف عشق زدی سر بباز چابک و چست
# [BOB][BOM]به صدق کوش که خورشيد زايد از نفست
# [BOM]که از دروغ سيه روی گشت صبح نخست
# [BOB][BOM]شدم ز دست تو شيدای کوه و دشت و هنوز
# [BOM]نمی‌کنی به ترحم نطاق سلسله سست
# [BOB][BOM]مرنج حافظ و از دلبران حفاظ مجوی
# [BOM]گناه باغ چه باشد چو اين گياه نرست
# [BOB][BOM]ما را ز خيال تو چه پروای شراب است
# [BOM]خم گو سر خود گير که خمخانه خراب است
# [BOB][BOM]گر خمر بهشت است بريزيد که بی دوست
# [BOM]هر شربت عذبم که دهی عين عذاب است
# [BOB][BOM]افسوس که شد دلبر و در ديده گريان
# [BOM]تحرير خيال خط او نقش بر آب است
# [BOB][BOM]بيدار شو ای ديده که ايمن نتوان بود
# [BOM]زين سيل دمادم که در اين منزل خواب است
# [BOB][BOM]معشوق عيان می‌گذرد بر تو وليکن
# [BOM]اغيار همی‌بيند از آن بسته نقاب است
# [BOB][BOM]گل بر رخ رنگين تو تا لطف عرق ديد
# [BOM]در آتش شوق از غم دل غرق گلاب است
# [BOB][BOM]سبز است در و دشت بيا تا نگذاريم
# [BOM]دست از سر آبی که جهان جمله سراب است
# [BOB][BOM]در کنج دماغم مطلب جای نصيحت
# [BOM]کاين گوشه پر از زمزمه چنگ و رباب است
# [BOB][BOM]حافظ چه شد ار عاشق و رند است و نظرباز
# [BOM]بس طور عجب لازم ايام شباب است
# [BOB][BOM]زلفت هزار دل به يکی تار مو ببست
# [BOM]راه هزار چاره گر از چار سو ببست
# [BOB][BOM]تا عاشقان به بوی نسيمش دهند جان
# [BOM]بگشود نافه‌ای و در آرزو ببست
# [BOB][BOM]شيدا از آن شدم که نگارم چو ماه نو
# [BOM]ابرو نمود و جلوه گری کرد و رو ببست
# [BOB][BOM]ساقی به چند رنگ می اندر پياله ريخت
# [BOM]اين نقش‌ها نگر که چه خوش در کدو ببست
# [BOB][BOM]يا رب چه غمزه کرد صراحی که خون خم
# [BOM]با نعره‌های قلقلش اندر گلو ببست
# [BOB][BOM]مطرب چه پرده ساخت که در پرده سماع
# [BOM]بر اهل وجد و حال در های و هو ببست
# [BOB][BOM]حافظ هر آن که عشق نورزيد و وصل خواست
# [BOM]احرام طوف کعبه دل بی وضو ببست
# [BOB][BOM]آن شب قدری که گويند اهل خلوت امشب است
# [BOM]يا رب اين تاثير دولت در کدامين کوکب است
# [BOB][BOM]تا به گيسوی تو دست ناسزايان کم رسد
# [BOM]هر دلی از حلقه‌ای در ذکر يارب يارب است
# [BOB][BOM]کشته چاه زنخدان توام کز هر طرف
# [BOM]صد هزارش گردن جان زير طوق غبغب است
# [BOB][BOM]شهسوار من که مه آيينه دار روی اوست
# [BOM]تاج خورشيد بلندش خاک نعل مرکب است
# [BOB][BOM]عکس خوی بر عارضش بين کفتاب گرم رو
# [BOM]در هوای آن عرق تا هست هر روزش تب است
# [BOB][BOM]من نخواهم کرد ترک لعل يار و جام می
# [BOM]زاهدان معذور داريدم که اينم مذهب است
# [BOB][BOM]اندر آن ساعت که بر پشت صبا بندند زين
# [BOM]با سليمان چون برانم من که مورم مرکب است
# [BOB][BOM]آن که ناوک بر دل من زير چشمی می‌زند
# [BOM]قوت جان حافظش در خنده زير لب است
# [BOB][BOM]آب حيوانش ز منقار بلاغت می‌چکد
# [BOM]زاغ کلک من به نام ايزد چه عالی مشرب است
# [BOB][BOM]خدا چو صورت ابروی دلگشای تو بست
# [BOM]گشاد کار من اندر کرشمه‌های تو بست
# [BOB][BOM]مرا و سرو چمن را به خاک راه نشاند
# [BOM]زمانه تا قصب نرگس قبای تو بست
# [BOB][BOM]ز کار ما و دل غنچه صد گره بگشود
# [BOM]نسيم گل چو دل اندر پی هوای تو بست
# [BOB][BOM]مرا به بند تو دوران چرخ راضی کرد
# [BOM]ولی چه سود که سررشته در رضای تو بست
# [BOB][BOM]چو نافه بر دل مسکين من گره مفکن
# [BOM]که عهد با سر زلف گره گشای تو بست
# [BOB][BOM]تو خود وصال دگر بودی ای نسيم وصال
# [BOM]خطا نگر که دل اميد در وفای تو بست
# [BOB][BOM]ز دست جور تو گفتم ز شهر خواهم رفت
# [BOM]به خنده گفت که حافظ برو که پای تو بست
# [BOB][BOM]خلوت گزيده را به تماشا چه حاجت است
# [BOM]چون کوی دوست هست به صحرا چه حاجت است
# [BOB][BOM]جانا به حاجتی که تو را هست با خدا
# [BOM]کخر دمی بپرس که ما را چه حاجت است
# [BOB][BOM]ای پادشاه حسن خدا را بسوختيم
# [BOM]آخر سال کن که گدا را چه حاجت است
# [BOB][BOM]ارباب حاجتيم و زبان سال نيست
# [BOM]در حضرت کريم تمنا چه حاجت است
# [BOB][BOM]محتاج قصه نيست گرت قصد خون ماست
# [BOM]چون رخت از آن توست به يغما چه حاجت است
# [BOB][BOM]جام جهان نماست ضمير منير دوست
# [BOM]اظهار احتياج خود آن جا چه حاجت است
# [BOB][BOM]آن شد که بار منت ملاح بردمی
# [BOM]گوهر چو دست داد به دريا چه حاجت است
# [BOB][BOM]ای مدعی برو که مرا با تو کار نيست
# [BOM]احباب حاضرند به اعدا چه حاجت است
# [BOB][BOM]ای عاشق گدا چو لب روح بخش يار
# [BOM]می‌داندت وظيفه تقاضا چه حاجت است
# [BOB][BOM]حافظ تو ختم کن که هنر خود عيان شود
# [BOM]با مدعی نزاع و محاکا چه حاجت است
# [BOB][BOM]رواق منظر چشم من آشيانه توست
# [BOM]کرم نما و فرود آ که خانه خانه توست
# [BOB][BOM]به لطف خال و خط از عارفان ربودی دل
# [BOM]لطيفه‌های عجب زير دام و دانه توست
# [BOB][BOM]دلت به وصل گل ای بلبل صبا خوش باد
# [BOM]که در چمن همه گلبانگ عاشقانه توست
# [BOB][BOM]علاج ضعف دل ما به لب حوالت کن
# [BOM]که اين مفرح ياقوت در خزانه توست
# [BOB][BOM]به تن مقصرم از دولت ملازمتت
# [BOM]ولی خلاصه جان خاک آستانه توست
# [BOB][BOM]من آن نيم که دهم نقد دل به هر شوخی
# [BOM]در خزانه به مهر تو و نشانه توست
# [BOB][BOM]تو خود چه لعبتی ای شهسوار شيرين کار
# [BOM]که توسنی چو فلک رام تازيانه توست
# [BOB][BOM]چه جای من که بلغزد سپهر شعبده باز
# [BOM]از اين حيل که در انبانه بهانه توست
# [BOB][BOM]سرود مجلست اکنون فلک به رقص آرد
# [BOM]که شعر حافظ شيرين سخن ترانه توست
# [BOB][BOM]برو به کار خود ای واعظ اين چه فريادست
# [BOM]مرا فتاد دل از ره تو را چه افتادست
# [BOB][BOM]ميان او که خدا آفريده است از هيچ
# [BOM]دقيقه‌ايست که هيچ آفريده نگشادست
# [BOB][BOM]به کام تا نرساند مرا لبش چون نای
# [BOM]نصيحت همه عالم به گوش من بادست
# [BOB][BOM]گدای کوی تو از هشت خلد مستغنيست
# [BOM]اسير عشق تو از هر دو عالم آزادست
# [BOB][BOM]اگر چه مستی عشقم خراب کرد ولی
# [BOM]اساس هستی من زان خراب آبادست
# [BOB][BOM]دلا منال ز بيداد و جور يار که يار
# [BOM]تو را نصيب همين کرد و اين از آن دادست
# [BOB][BOM]برو فسانه مخوان و فسون مدم حافظ
# [BOM]کز اين فسانه و افسون مرا بسی يادست
# [BOB][BOM]تا سر زلف تو در دست نسيم افتادست
# [BOM]دل سودازده از غصه دو نيم افتادست
# [BOB][BOM]چشم جادوی تو خود عين سواد سحر است
# [BOM]ليکن اين هست که اين نسخه سقيم افتادست
# [BOB][BOM]در خم زلف تو آن خال سيه دانی چيست
# [BOM]نقطه دوده که در حلقه جيم افتادست
# [BOB][BOM]زلف مشکين تو در گلشن فردوس عذار
# [BOM]چيست طاووس که در باغ نعيم افتادست
# [BOB][BOM]دل من در هوس روی تو ای مونس جان
# [BOM]خاک راهيست که در دست نسيم افتادست
# [BOB][BOM]همچو گرد اين تن خاکی نتواند برخاست
# [BOM]از سر کوی تو زان رو که عظيم افتادست
# [BOB][BOM]سايه قد تو بر قالبم ای عيسی دم
# [BOM]عکس روحيست که بر عظم رميم افتادست
# [BOB][BOM]آن که جز کعبه مقامش نبد از ياد لبت
# [BOM]بر در ميکده ديدم که مقيم افتادست
# [BOB][BOM]حافظ گمشده را با غمت ای يار عزيز
# [BOM]اتحاديست که در عهد قديم افتادست
# [BOB][BOM]بيا که قصر امل سخت سست بنيادست
# [BOM]بيار باده که بنياد عمر بر بادست
# [BOB][BOM]غلام همت آنم که زير چرخ کبود
# [BOM]ز هر چه رنگ تعلق پذيرد آزادست
# [BOB][BOM]چه گويمت که به ميخانه دوش مست و خراب
# [BOM]سروش عالم غيبم چه مژده‌ها دادست
# [BOB][BOM]که ای بلندنظر شاهباز سدره نشين
# [BOM]نشيمن تو نه اين کنج محنت آبادست
# [BOB][BOM]تو را ز کنگره عرش می‌زنند صفير
# [BOM]ندانمت که در اين دامگه چه افتادست
# [BOB][BOM]نصيحتی کنمت ياد گير و در عمل آر
# [BOM]که اين حديث ز پير طريقتم يادست
# [BOB][BOM]غم جهان مخور و پند من مبر از ياد
# [BOM]که اين لطيفه عشقم ز ره روی يادست
# [BOB][BOM]رضا به داده بده وز جبين گره بگشای
# [BOM]که بر من و تو در اختيار نگشادست
# [BOB][BOM]مجو درستی عهد از جهان سست نهاد
# [BOM]که اين عجوز عروس هزاردامادست
# [BOB][BOM]نشان عهد و وفا نيست در تبسم گل
# [BOM]بنال بلبل بی دل که جای فريادست
# [BOB][BOM]حسد چه می‌بری ای سست نظم بر حافظ
# [BOM]قبول خاطر و لطف سخن خدادادست
# [BOB][BOM]بی مهر رخت روز مرا نور نماندست
# [BOM]وز عمر مرا جز شب ديجور نماندست
# [BOB][BOM]هنگام وداع تو ز بس گريه که کردم
# [BOM]دور از رخ تو چشم مرا نور نماندست
# [BOB][BOM]می‌رفت خيال تو ز چشم من و می‌گفت
# [BOM]هيهات از اين گوشه که معمور نماندست
# [BOB][BOM]وصل تو اجل را ز سرم دور همی‌داشت
# [BOM]از دولت هجر تو کنون دور نماندست
# [BOB][BOM]نزديک شد آن دم که رقيب تو بگويد
# [BOM]دور از رخت اين خسته رنجور نماندست
# [BOB][BOM]صبر است مرا چاره هجران تو ليکن
# [BOM]چون صبر توان کرد که مقدور نماندست
# [BOB][BOM]در هجر تو گر چشم مرا آب روان است
# [BOM]گو خون جگر ريز که معذور نماندست
# [BOB][BOM]حافظ ز غم از گريه نپرداخت به خنده
# [BOM]ماتم زده را داعيه سور نماندست
# [BOB][BOM]باغ مرا چه حاجت سرو و صنوبر است
# [BOM]شمشاد خانه پرور ما از که کمتر است
# [BOB][BOM]ای نازنين پسر تو چه مذهب گرفته‌ای
# [BOM]کت خون ما حلالتر از شير مادر است
# [BOB][BOM]چون نقش غم ز دور ببينی شراب خواه
# [BOM]تشخيص کرده‌ايم و مداوا مقرر است
# [BOB][BOM]از آستان پير مغان سر چرا کشيم
# [BOM]دولت در آن سرا و گشايش در آن در است
# [BOB][BOM]يک قصه بيش نيست غم عشق وين عجب
# [BOM]کز هر زبان که می‌شنوم نامکرر است
# [BOB][BOM]دی وعده داد وصلم و در سر شراب داشت
# [BOM]امروز تا چه گويد و بازش چه در سر است
# [BOB][BOM]شيراز و آب رکنی و اين باد خوش نسيم
# [BOM]عيبش مکن که خال رخ هفت کشور است
# [BOB][BOM]فرق است از آب خضر که ظلمات جای او است
# [BOM]تا آب ما که منبعش الله اکبر است
# [BOB][BOM]ما آبروی فقر و قناعت نمی‌بريم
# [BOM]با پادشه بگوی که روزی مقدر است
# [BOB][BOM]حافظ چه طرفه شاخ نباتيست کلک تو
# [BOM]کش ميوه دلپذيرتر از شهد و شکر است
# [BOB][BOM]المنه لله که در ميکده باز است
# [BOM]زان رو که مرا بر در او روی نياز است
# [BOB][BOM]خم‌ها همه در جوش و خروشند ز مستی
# [BOM]وان می که در آن جاست حقيقت نه مجاز است
# [BOB][BOM]از وی همه مستی و غرور است و تکبر
# [BOM]وز ما همه بيچارگی و عجز و نياز است
# [BOB][BOM]رازی که بر غير نگفتيم و نگوييم
# [BOM]با دوست بگوييم که او محرم راز است
# [BOB][BOM]شرح شکن زلف خم اندر خم جانان
# [BOM]کوته نتوان کرد که اين قصه دراز است
# [BOB][BOM]بار دل مجنون و خم طره ليلی
# [BOM]رخساره محمود و کف پای اياز است
# [BOB][BOM]بردوخته‌ام ديده چو باز از همه عالم
# [BOM]تا ديده من بر رخ زيبای تو باز است
# [BOB][BOM]در کعبه کوی تو هر آن کس که بيايد
# [BOM]از قبله ابروی تو در عين نماز است
# [BOB][BOM]ای مجلسيان سوز دل حافظ مسکين
# [BOM]از شمع بپرسيد که در سوز و گداز است
# [BOB][BOM]اگر چه باده فرح بخش و باد گل‌بيز است
# [BOM]به بانگ چنگ مخور می که محتسب تيز است
# [BOB][BOM]صراحی ای و حريفی گرت به چنگ افتد
# [BOM]به عقل نوش که ايام فتنه انگيز است
# [BOB][BOM]در آستين مرقع پياله پنهان کن
# [BOM]که همچو چشم صراحی زمانه خون‌ريز است
# [BOB][BOM]به آب ديده بشوييم خرقه‌ها از می
# [BOM]که موسم ورع و روزگار پرهيز است
# [BOB][BOM]مجوی عيش خوش از دور باژگون سپهر
# [BOM]که صاف اين سر خم جمله دردی آميز است
# [BOB][BOM]سپهر برشده پرويزنيست خون افشان
# [BOM]که ريزه‌اش سر کسری و تاج پرويز است
# [BOB][BOM]عراق و فارس گرفتی به شعر خوش حافظ
# [BOM]بيا که نوبت بغداد و وقت تبريز است
# [BOB][BOM]حال دل با تو گفتنم هوس است
# [BOM]خبر دل شنفتنم هوس است
# [BOB][BOM]طمع خام بين که قصه فاش
# [BOM]از رقيبان نهفتنم هوس است
# [BOB][BOM]شب قدری چنين عزيز و شريف
# [BOM]با تو تا روز خفتنم هوس است
# [BOB][BOM]وه که دردانه‌ای چنين نازک
# [BOM]در شب تار سفتنم هوس است
# [BOB][BOM]ای صبا امشبم مدد فرمای
# [BOM]که سحرگه شکفتنم هوس است
# [BOB][BOM]از برای شرف به نوک مژه
# [BOM]خاک راه تو رفتنم هوس است
# [BOB][BOM]همچو حافظ به رغم مدعيان
# [BOM]شعر رندانه گفتنم هوس است
# [BOB][BOM]صحن بستان ذوق بخش و صحبت ياران خوش است
# [BOM]وقت گل خوش باد کز وی وقت ميخواران خوش است
# [BOB][BOM]از صبا هر دم مشام جان ما خوش می‌شود
# [BOM]آری آری طيب انفاس هواداران خوش است
# [BOB][BOM]ناگشوده گل نقاب آهنگ رحلت ساز کرد
# [BOM]ناله کن بلبل که گلبانگ دل افکاران خوش است
# [BOB][BOM]مرغ خوشخوان را بشارت باد کاندر راه عشق
# [BOM]دوست را با ناله شب‌های بيداران خوش است
# [BOB][BOM]نيست در بازار عالم خوشدلی ور زان که هست
# [BOM]شيوه رندی و خوش باشی عياران خوش است
# [BOB][BOM]از زبان سوسن آزاده‌ام آمد به گوش
# [BOM]کاندر اين دير کهن کار سبکباران خوش است
# [BOB][BOM]حافظا ترک جهان گفتن طريق خوشدليست
# [BOM]تا نپنداری که احوال جهان داران خوش است
# [BOB][BOM]کنون که بر کف گل جام باده صاف است
# [BOM]به صد هزار زبان بلبلش در اوصاف است
# [BOB][BOM]بخواه دفتر اشعار و راه صحرا گير
# [BOM]چه وقت مدرسه و بحث کشف کشاف است
# [BOB][BOM]فقيه مدرسه دی مست بود و فتوی داد
# [BOM]که می حرام ولی به ز مال اوقاف است
# [BOB][BOM]به درد و صاف تو را حکم نيست خوش درکش
# [BOM]که هر چه ساقی ما کرد عين الطاف است
# [BOB][BOM]ببر ز خلق و چو عنقا قياس کار بگير
# [BOM]که صيت گوشه نشينان ز قاف تا قاف است
# [BOB][BOM]حديث مدعيان و خيال همکاران
# [BOM]همان حکايت زردوز و بورياباف است
# [BOB][BOM]خموش حافظ و اين نکته‌های چون زر سرخ
# [BOM]نگاه دار که قلاب شهر صراف است
# [BOB][BOM]در اين زمانه رفيقی که خالی از خلل است
# [BOM]صراحی می ناب و سفينه غزل است
# [BOB][BOM]جريده رو که گذرگاه عافيت تنگ است
# [BOM]پياله گير که عمر عزيز بی‌بدل است
# [BOB][BOM]نه من ز بی عملی در جهان ملولم و بس
# [BOM]ملالت علما هم ز علم بی عمل است
# [BOB][BOM]به چشم عقل در اين رهگذار پرآشوب
# [BOM]جهان و کار جهان بی‌ثبات و بی‌محل است
# [BOB][BOM]بگير طره مه چهره‌ای و قصه مخوان
# [BOM]که سعد و نحس ز تاثير زهره و زحل است
# [BOB][BOM]دلم اميد فراوان به وصل روی تو داشت
# [BOM]ولی اجل به ره عمر رهزن امل است
# [BOB][BOM]به هيچ دور نخواهند يافت هشيارش
# [BOM]چنين که حافظ ما مست باده ازل است
# [BOB][BOM]گل در بر و می در کف و معشوق به کام است
# [BOM]سلطان جهانم به چنين روز غلام است
# [BOB][BOM]گو شمع مياريد در اين جمع که امشب
# [BOM]در مجلس ما ماه رخ دوست تمام است
# [BOB][BOM]در مذهب ما باده حلال است وليکن
# [BOM]بی روی تو ای سرو گل اندام حرام است
# [BOB][BOM]گوشم همه بر قول نی و نغمه چنگ است
# [BOM]چشمم همه بر لعل لب و گردش جام است
# [BOB][BOM]در مجلس ما عطر مياميز که ما را
# [BOM]هر لحظه ز گيسوی تو خوش بوی مشام است
# [BOB][BOM]از چاشنی قند مگو هيچ و ز شکر
# [BOM]زان رو که مرا از لب شيرين تو کام است
# [BOB][BOM]تا گنج غمت در دل ويرانه مقيم است
# [BOM]همواره مرا کوی خرابات مقام است
# [BOB][BOM]از ننگ چه گويی که مرا نام ز ننگ است
# [BOM]وز نام چه پرسی که مرا ننگ ز نام است
# [BOB][BOM]ميخواره و سرگشته و رنديم و نظرباز
# [BOM]وان کس که چو ما نيست در اين شهر کدام است
# [BOB][BOM]با محتسبم عيب مگوييد که او نيز
# [BOM]پيوسته چو ما در طلب عيش مدام است
# [BOB][BOM]حافظ منشين بی می و معشوق زمانی
# [BOM]کايام گل و ياسمن و عيد صيام است
# [BOB][BOM]به کوی ميکده هر سالکی که ره دانست
# [BOM]دری دگر زدن انديشه تبه دانست
# [BOB][BOM]زمانه افسر رندی نداد جز به کسی
# [BOM]که سرفرازی عالم در اين کله دانست
# [BOB][BOM]بر آستانه ميخانه هر که يافت رهی
# [BOM]ز فيض جام می اسرار خانقه دانست
# [BOB][BOM]هر آن که راز دو عالم ز خط ساغر خواند
# [BOM]رموز جام جم از نقش خاک ره دانست
# [BOB][BOM]ورای طاعت ديوانگان ز ما مطلب
# [BOM]که شيخ مذهب ما عاقلی گنه دانست
# [BOB][BOM]دلم ز نرگس ساقی امان نخواست به جان
# [BOM]چرا که شيوه آن ترک دل سيه دانست
# [BOB][BOM]ز جور کوکب طالع سحرگهان چشمم
# [BOM]چنان گريست که ناهيد ديد و مه دانست
# [BOB][BOM]حديث حافظ و ساغر که می‌زند پنهان
# [BOM]چه جای محتسب و شحنه پادشه دانست
# [BOB][BOM]بلندمرتبه شاهی که نه رواق سپهر
# [BOM]نمونه‌ای ز خم طاق بارگه دانست
# [BOB][BOM]صوفی از پرتو می راز نهانی دانست
# [BOM]گوهر هر کس از اين لعل توانی دانست
# [BOB][BOM]قدر مجموعه گل مرغ سحر داند و بس
# [BOM]که نه هر کو ورقی خواند معانی دانست
# [BOB][BOM]عرضه کردم دو جهان بر دل کارافتاده
# [BOM]بجز از عشق تو باقی همه فانی دانست
# [BOB][BOM]آن شد اکنون که ز ابنای عوام انديشم
# [BOM]محتسب نيز در اين عيش نهانی دانست
# [BOB][BOM]دلبر آسايش ما مصلحت وقت نديد
# [BOM]ور نه از جانب ما دل نگرانی دانست
# [BOB][BOM]سنگ و گل را کند از يمن نظر لعل و عقيق
# [BOM]هر که قدر نفس باد يمانی دانست
# [BOB][BOM]ای که از دفتر عقل آيت عشق آموزی
# [BOM]ترسم اين نکته به تحقيق ندانی دانست
# [BOB][BOM]می بياور که ننازد به گل باغ جهان
# [BOM]هر که غارتگری باد خزانی دانست
# [BOB][BOM]حافظ اين گوهر منظوم که از طبع انگيخت
# [BOM]ز اثر تربيت آصف ثانی دانست
# [BOB][BOM]روضه خلد برين خلوت درويشان است
# [BOM]مايه محتشمی خدمت درويشان است
# [BOB][BOM]گنج عزلت که طلسمات عجايب دارد
# [BOM]فتح آن در نظر رحمت درويشان است
# [BOB][BOM]قصر فردوس که رضوانش به دربانی رفت
# [BOM]منظری از چمن نزهت درويشان است
# [BOB][BOM]آن چه زر می‌شود از پرتو آن قلب سياه
# [BOM]کيمياييست که در صحبت درويشان است
# [BOB][BOM]آن که پيشش بنهد تاج تکبر خورشيد
# [BOM]کبرياييست که در حشمت درويشان است
# [BOB][BOM]دولتی را که نباشد غم از آسيب زوال
# [BOM]بی تکلف بشنو دولت درويشان است
# [BOB][BOM]خسروان قبله حاجات جهانند ولی
# [BOM]سببش بندگی حضرت درويشان است
# [BOB][BOM]روی مقصود که شاهان به دعا می‌طلبند
# [BOM]مظهرش آينه طلعت درويشان است
# [BOB][BOM]از کران تا به کران لشکر ظلم است ولی
# [BOM]از ازل تا به ابد فرصت درويشان است
# [BOB][BOM]ای توانگر مفروش اين همه نخوت که تو را
# [BOM]سر و زر در کنف همت درويشان است
# [BOB][BOM]گنج قارون که فرو می‌شود از قهر هنوز
# [BOM]خوانده باشی که هم از غيرت درويشان است
# [BOB][BOM]من غلام نظر آصف عهدم کو را
# [BOM]صورت خواجگی و سيرت درويشان است
# [BOB][BOM]حافظ ار آب حيات ازلی می‌خواهی
# [BOM]منبعش خاک در خلوت درويشان است
# [BOB][BOM]به دام زلف تو دل مبتلای خويشتن است
# [BOM]بکش به غمزه که اينش سزای خويشتن است
# [BOB][BOM]گرت ز دست برآيد مراد خاطر ما
# [BOM]به دست باش که خيری به جای خويشتن است
# [BOB][BOM]به جانت ای بت شيرين دهن که همچون شمع
# [BOM]شبان تيره مرادم فنای خويشتن است
# [BOB][BOM]چو رای عشق زدی با تو گفتم ای بلبل
# [BOM]مکن که آن گل خندان برای خويشتن است
# [BOB][BOM]به مشک چين و چگل نيست بوی گل محتاج
# [BOM]که نافه‌هاش ز بند قبای خويشتن است
# [BOB][BOM]مرو به خانه ارباب بی‌مروت دهر
# [BOM]که گنج عافيتت در سرای خويشتن است
# [BOB][BOM]بسوخت حافظ و در شرط عشقبازی او
# [BOM]هنوز بر سر عهد و وفای خويشتن است
# [BOB][BOM]لعل سيراب به خون تشنه لب يار من است
# [BOM]وز پی ديدن او دادن جان کار من است
# [BOB][BOM]شرم از آن چشم سيه بادش و مژگان دراز
# [BOM]هر که دل بردن او ديد و در انکار من است
# [BOB][BOM]ساروان رخت به دروازه مبر کان سر کو
# [BOM]شاهراهيست که منزلگه دلدار من است
# [BOB][BOM]بنده طالع خويشم که در اين قحط وفا
# [BOM]عشق آن لولی سرمست خريدار من است
# [BOB][BOM]طبله عطر گل و زلف عبيرافشانش
# [BOM]فيض يک شمه ز بوی خوش عطار من است
# [BOB][BOM]باغبان همچو نسيمم ز در خويش مران
# [BOM]کب گلزار تو از اشک چو گلنار من است
# [BOB][BOM]شربت قند و گلاب از لب يارم فرمود
# [BOM]نرگس او که طبيب دل بيمار من است
# [BOB][BOM]آن که در طرز غزل نکته به حافظ آموخت
# [BOM]يار شيرين سخن نادره گفتار من است
# [BOB][BOM]روزگاريست که سودای بتان دين من است
# [BOM]غم اين کار نشاط دل غمگين من است
# [BOB][BOM]ديدن روی تو را ديده جان بين بايد
# [BOM]وين کجا مرتبه چشم جهان بين من است
# [BOB][BOM]يار من باش که زيب فلک و زينت دهر
# [BOM]از مه روی تو و اشک چو پروين من است
# [BOB][BOM]تا مرا عشق تو تعليم سخن گفتن کرد
# [BOM]خلق را ورد زبان مدحت و تحسين من است
# [BOB][BOM]دولت فقر خدايا به من ارزانی دار
# [BOM]کاين کرامت سبب حشمت و تمکين من است
# [BOB][BOM]واعظ شحنه شناس اين عظمت گو مفروش
# [BOM]زان که منزلگه سلطان دل مسکين من است
# [BOB][BOM]يا رب اين کعبه مقصود تماشاگه کيست
# [BOM]که مغيلان طريقش گل و نسرين من است
# [BOB][BOM]حافظ از حشمت پرويز دگر قصه مخوان
# [BOM]که لبش جرعه کش خسرو شيرين من است
# [BOB][BOM]منم که گوشه ميخانه خانقاه من است
# [BOM]دعای پير مغان ورد صبحگاه من است
# [BOB][BOM]گرم ترانه چنگ صبوح نيست چه باک
# [BOM]نوای من به سحر آه عذرخواه من است
# [BOB][BOM]ز پادشاه و گدا فارغم بحمدالله
# [BOM]گدای خاک در دوست پادشاه من است
# [BOB][BOM]غرض ز مسجد و ميخانه‌ام وصال شماست
# [BOM]جز اين خيال ندارم خدا گواه من است
# [BOB][BOM]مگر به تيغ اجل خيمه برکنم ور نی
# [BOM]رميدن از در دولت نه رسم و راه من است
# [BOB][BOM]از آن زمان که بر اين آستان نهادم روی
# [BOM]فراز مسند خورشيد تکيه گاه من است
# [BOB][BOM]گناه اگر چه نبود اختيار ما حافظ
# [BOM]تو در طريق ادب باش و گو گناه من است
# [BOB][BOM]ز گريه مردم چشمم نشسته در خون است
# [BOM]ببين که در طلبت حال مردمان چون است
# [BOB][BOM]به ياد لعل تو و چشم مست ميگونت
# [BOM]ز جام غم می لعلی که می‌خورم خون است
# [BOB][BOM]ز مشرق سر کو آفتاب طلعت تو
# [BOM]اگر طلوع کند طالعم همايون است
# [BOB][BOM]حکايت لب شيرين کلام فرهاد است
# [BOM]شکنج طره ليلی مقام مجنون است
# [BOB][BOM]دلم بجو که قدت همچو سرو دلجوی است
# [BOM]سخن بگو که کلامت لطيف و موزون است
# [BOB][BOM]ز دور باده به جان راحتی رسان ساقی
# [BOM]که رنج خاطرم از جور دور گردون است
# [BOB][BOM]از آن دمی که ز چشمم برفت رود عزيز
# [BOM]کنار دامن من همچو رود جيحون است
# [BOB][BOM]چگونه شاد شود اندرون غمگينم
# [BOM]به اختيار که از اختيار بيرون است
# [BOB][BOM]ز بيخودی طلب يار می‌کند حافظ
# [BOM]چو مفلسی که طلبکار گنج قارون است
# [BOB][BOM]خم زلف تو دام کفر و دين است
# [BOM]ز کارستان او يک شمه اين است
# [BOB][BOM]جمالت معجز حسن است ليکن
# [BOM]حديث غمزه‌ات سحر مبين است
# [BOB][BOM]ز چشم شوخ تو جان کی توان برد
# [BOM]که دايم با کمان اندر کمين است
# [BOB][BOM]بر آن چشم سيه صد آفرين باد
# [BOM]که در عاشق کشی سحرآفرين است
# [BOB][BOM]عجب علميست علم هيت عشق
# [BOM]که چرخ هشتمش هفتم زمين است
# [BOB][BOM]تو پنداری که بدگو رفت و جان برد
# [BOM]حسابش با کرام الکاتبين است
# [BOB][BOM]مشو حافظ ز کيد زلفش ايمن
# [BOM]که دل برد و کنون دربند دين است
# [BOB][BOM]دل سراپرده محبت اوست
# [BOM]ديده آيينه دار طلعت اوست
# [BOB][BOM]من که سر درنياورم به دو کون
# [BOM]گردنم زير بار منت اوست
# [BOB][BOM]تو و طوبی و ما و قامت يار
# [BOM]فکر هر کس به قدر همت اوست
# [BOB][BOM]گر من آلوده دامنم چه عجب
# [BOM]همه عالم گواه عصمت اوست
# [BOB][BOM]من که باشم در آن حرم که صبا
# [BOM]پرده دار حريم حرمت اوست
# [BOB][BOM]بی خيالش مباد منظر چشم
# [BOM]زان که اين گوشه جای خلوت اوست
# [BOB][BOM]هر گل نو که شد چمن آرای
# [BOM]ز اثر رنگ و بوی صحبت اوست
# [BOB][BOM]دور مجنون گذشت و نوبت ماست
# [BOM]هر کسی پنج روز نوبت اوست
# [BOB][BOM]ملکت عاشقی و گنج طرب
# [BOM]هر چه دارم ز يمن همت اوست
# [BOB][BOM]من و دل گر فدا شديم چه باک
# [BOM]غرض اندر ميان سلامت اوست
# [BOB][BOM]فقر ظاهر مبين که حافظ را
# [BOM]سينه گنجينه محبت اوست
# [BOB][BOM]آن سيه چرده که شيرينی عالم با اوست
# [BOM]چشم ميگون لب خندان دل خرم با اوست
# [BOB][BOM]گر چه شيرين دهنان پادشهانند ولی
# [BOM]او سليمان زمان است که خاتم با اوست
# [BOB][BOM]روی خوب است و کمال هنر و دامن پاک
# [BOM]لاجرم همت پاکان دو عالم با اوست
# [BOB][BOM]خال مشکين که بدان عارض گندمگون است
# [BOM]سر آن دانه که شد رهزن آدم با اوست
# [BOB][BOM]دلبرم عزم سفر کرد خدا را ياران
# [BOM]چه کنم با دل مجروح که مرهم با اوست
# [BOB][BOM]با که اين نکته توان گفت که آن سنگين دل
# [BOM]کشت ما را و دم عيسی مريم با اوست
# [BOB][BOM]حافظ از معتقدان است گرامی دارش
# [BOM]زان که بخشايش بس روح مکرم با اوست
# [BOB][BOM]سر ارادت ما و آستان حضرت دوست
# [BOM]که هر چه بر سر ما می‌رود ارادت اوست
# [BOB][BOM]نظير دوست نديدم اگر چه از مه و مهر
# [BOM]نهادم آينه‌ها در مقابل رخ دوست
# [BOB][BOM]صبا ز حال دل تنگ ما چه شرح دهد
# [BOM]که چون شکنج ورق‌های غنچه تو بر توست
# [BOB][BOM]نه من سبوکش اين دير رندسوزم و بس
# [BOM]بسا سرا که در اين کارخانه سنگ و سبوست
# [BOB][BOM]مگر تو شانه زدی زلف عنبرافشان را
# [BOM]که باد غاليه سا گشت و خاک عنبربوست
# [BOB][BOM]نثار روی تو هر برگ گل که در چمن است
# [BOM]فدای قد تو هر سروبن که بر لب جوست
# [BOB][BOM]زبان ناطقه در وصف شوق نالان است
# [BOM]چه جای کلک بريده زبان بيهده گوست
# [BOB][BOM]رخ تو در دلم آمد مراد خواهم يافت
# [BOM]چرا که حال نکو در قفای فال نکوست
# [BOB][BOM]نه اين زمان دل حافظ در آتش هوس است
# [BOM]که داغدار ازل همچو لاله خودروست
# [BOB][BOM]دارم اميد عاطفتی از جانب دوست
# [BOM]کردم جنايتی و اميدم به عفو اوست
# [BOB][BOM]دانم که بگذرد ز سر جرم من که او
# [BOM]گر چه پريوش است وليکن فرشته خوست
# [BOB][BOM]چندان گريستم که هر کس که برگذشت
# [BOM]در اشک ما چو ديد روان گفت کاين چه جوست
# [BOB][BOM]هيچ است آن دهان و نبينم از او نشان
# [BOM]موی است آن ميان و ندانم که آن چه موست
# [BOB][BOM]دارم عجب ز نقش خيالش که چون نرفت
# [BOM]از ديده‌ام که دم به دمش کار شست و شوست
# [BOB][BOM]بی گفت و گوی زلف تو دل را همی‌کشد
# [BOM]با زلف دلکش تو که را روی گفت و گوست
# [BOB][BOM]عمريست تا ز زلف تو بويی شنيده‌ام
# [BOM]زان بوی در مشام دل من هنوز بوست
# [BOB][BOM]حافظ بد است حال پريشان تو ولی
# [BOM]بر بوی زلف يار پريشانيت نکوست
# [BOB][BOM]آن پيک نامور که رسيد از ديار دوست
# [BOM]آورد حرز جان ز خط مشکبار دوست
# [BOB][BOM]خوش می‌دهد نشان جلال و جمال يار
# [BOM]خوش می‌کند حکايت عز و وقار دوست
# [BOB][BOM]دل دادمش به مژده و خجلت همی‌برم
# [BOM]زين نقد قلب خويش که کردم نثار دوست
# [BOB][BOM]شکر خدا که از مدد بخت کارساز
# [BOM]بر حسب آرزوست همه کار و بار دوست
# [BOB][BOM]سير سپهر و دور قمر را چه اختيار
# [BOM]در گردشند بر حسب اختيار دوست
# [BOB][BOM]گر باد فتنه هر دو جهان را به هم زند
# [BOM]ما و چراغ چشم و ره انتظار دوست
# [BOB][BOM]کحل الجواهری به من آر ای نسيم صبح
# [BOM]زان خاک نيکبخت که شد رهگذار دوست
# [BOB][BOM]ماييم و آستانه عشق و سر نياز
# [BOM]تا خواب خوش که را برد اندر کنار دوست
# [BOB][BOM]دشمن به قصد حافظ اگر دم زند چه باک
# [BOM]منت خدای را که نيم شرمسار دوست
# [BOB][BOM]صبا اگر گذری افتدت به کشور دوست
# [BOM]بيار نفحه‌ای از گيسوی معنبر دوست
# [BOB][BOM]به جان او که به شکرانه جان برافشانم
# [BOM]اگر به سوی من آری پيامی از بر دوست
# [BOB][BOM]و گر چنان که در آن حضرتت نباشد بار
# [BOM]برای ديده بياور غباری از در دوست
# [BOB][BOM]من گدا و تمنای وصل او هيهات
# [BOM]مگر به خواب ببينم خيال منظر دوست
# [BOB][BOM]دل صنوبريم همچو بيد لرزان است
# [BOM]ز حسرت قد و بالای چون صنوبر دوست
# [BOB][BOM]اگر چه دوست به چيزی نمی‌خرد ما را
# [BOM]به عالمی نفروشيم مويی از سر دوست
# [BOB][BOM]چه باشد ار شود از بند غم دلش آزاد
# [BOM]چو هست حافظ مسکين غلام و چاکر دوست
# [BOB][BOM]مرحبا ای پيک مشتاقان بده پيغام دوست
# [BOM]تا کنم جان از سر رغبت فدای نام دوست
# [BOB][BOM]واله و شيداست دايم همچو بلبل در قفس
# [BOM]طوطی طبعم ز عشق شکر و بادام دوست
# [BOB][BOM]زلف او دام است و خالش دانه آن دام و من
# [BOM]بر اميد دانه‌ای افتاده‌ام در دام دوست
# [BOB][BOM]سر ز مستی برنگيرد تا به صبح روز حشر
# [BOM]هر که چون من در ازل يک جرعه خورد از جام دوست
# [BOB][BOM]بس نگويم شمه‌ای از شرح شوق خود از آنک
# [BOM]دردسر باشد نمودن بيش از اين ابرام دوست
# [BOB][BOM]گر دهد دستم کشم در ديده همچون توتيا
# [BOM]خاک راهی کان مشرف گردد از اقدام دوست
# [BOB][BOM]ميل من سوی وصال و قصد او سوی فراق
# [BOM]ترک کام خود گرفتم تا برآيد کام دوست
# [BOB][BOM]حافظ اندر درد او می‌سوز و بی‌درمان بساز
# [BOM]زان که درمانی ندارد درد بی‌آرام دوست
# [BOB][BOM]روی تو کس نديد و هزارت رقيب هست
# [BOM]در غنچه‌ای هنوز و صدت عندليب هست
# [BOB][BOM]گر آمدم به کوی تو چندان غريب نيست
# [BOM]چون من در آن ديار هزاران غريب هست
# [BOB][BOM]در عشق خانقاه و خرابات فرق نيست
# [BOM]هر جا که هست پرتو روی حبيب هست
# [BOB][BOM]آن جا که کار صومعه را جلوه می‌دهند
# [BOM]ناقوس دير راهب و نام صليب هست
# [BOB][BOM]عاشق که شد که يار به حالش نظر نکرد
# [BOM]ای خواجه درد نيست وگرنه طبيب هست
# [BOB][BOM]فرياد حافظ اين همه آخر به هرزه نيست
# [BOM]هم قصه‌ای غريب و حديثی عجيب هست
# [BOB][BOM]اگر چه عرض هنر پيش يار بی‌ادبيست
# [BOM]زبان خموش وليکن دهان پر از عربيست
# [BOB][BOM]پری نهفته رخ و ديو در کرشمه حسن
# [BOM]بسوخت ديده ز حيرت که اين چه بوالعجبيست
# [BOB][BOM]در اين چمن گل بی خار کس نچيد آری
# [BOM]چراغ مصطفوی با شرار بولهبيست
# [BOB][BOM]سبب مپرس که چرخ از چه سفله پرور شد
# [BOM]که کام بخشی او را بهانه بی سببيست
# [BOB][BOM]به نيم جو نخرم طاق خانقاه و رباط
# [BOM]مرا که مصطبه ايوان و پای خم طنبيست
# [BOB][BOM]جمال دختر رز نور چشم ماست مگر
# [BOM]که در نقاب زجاجی و پرده عنبيست
# [BOB][BOM]هزار عقل و ادب داشتم من ای خواجه
# [BOM]کنون که مست خرابم صلاح بی‌ادبيست
# [BOB][BOM]بيار می که چو حافظ هزارم استظهار
# [BOM]به گريه سحری و نياز نيم شبيست
# [BOB][BOM]خوشتر ز عيش و صحبت و باغ و بهار چيست
# [BOM]ساقی کجاست گو سبب انتظار چيست
# [BOB][BOM]هر وقت خوش که دست دهد مغتنم شمار
# [BOM]کس را وقوف نيست که انجام کار چيست
# [BOB][BOM]پيوند عمر بسته به موييست هوش دار
# [BOM]غمخوار خويش باش غم روزگار چيست
# [BOB][BOM]معنی آب زندگی و روضه ارم
# [BOM]جز طرف جويبار و می خوشگوار چيست
# [BOB][BOM]مستور و مست هر دو چو از يک قبيله‌اند
# [BOM]ما دل به عشوه که دهيم اختيار چيست
# [BOB][BOM]راز درون پرده چه داند فلک خموش
# [BOM]ای مدعی نزاع تو با پرده دار چيست
# [BOB][BOM]سهو و خطای بنده گرش اعتبار نيست
# [BOM]معنی عفو و رحمت آمرزگار چيست
# [BOB][BOM]زاهد شراب کوثر و حافظ پياله خواست
# [BOM]تا در ميانه خواسته کردگار چيست
# [BOB][BOM]بنال بلبل اگر با منت سر ياريست
# [BOM]که ما دو عاشق زاريم و کار ما زاريست
# [BOB][BOM]در آن زمين که نسيمی وزد ز طره دوست
# [BOM]چه جای دم زدن نافه‌های تاتاريست
# [BOB][BOM]بيار باده که رنگين کنيم جامه زرق
# [BOM]که مست جام غروريم و نام هشياريست
# [BOB][BOM]خيال زلف تو پختن نه کار هر خاميست
# [BOM]که زير سلسله رفتن طريق عياريست
# [BOB][BOM]لطيفه‌ايست نهانی که عشق از او خيزد
# [BOM]که نام آن نه لب لعل و خط زنگاريست
# [BOB][BOM]جمال شخص نه چشم است و زلف و عارض و خال
# [BOM]هزار نکته در اين کار و بار دلداريست
# [BOB][BOM]قلندران حقيقت به نيم جو نخرند
# [BOM]قبای اطلس آن کس که از هنر عاريست
# [BOB][BOM]بر آستان تو مشکل توان رسيد آری
# [BOM]عروج بر فلک سروری به دشواريست
# [BOB][BOM]سحر کرشمه چشمت به خواب می‌ديدم
# [BOM]زهی مراتب خوابی که به ز بيداريست
# [BOB][BOM]دلش به ناله ميازار و ختم کن حافظ
# [BOM]که رستگاری جاويد در کم آزاريست
# [BOB][BOM]يا رب اين شمع دل افروز ز کاشانه کيست
# [BOM]جان ما سوخت بپرسيد که جانانه کيست
# [BOB][BOM]حاليا خانه برانداز دل و دين من است
# [BOM]تا در آغوش که می‌خسبد و همخانه کيست
# [BOB][BOM]باده لعل لبش کز لب من دور مباد
# [BOM]راح روح که و پيمان ده پيمانه کيست
# [BOB][BOM]دولت صحبت آن شمع سعادت پرتو
# [BOM]بازپرسيد خدا را که به پروانه کيست
# [BOB][BOM]می‌دهد هر کسش افسونی و معلوم نشد
# [BOM]که دل نازک او مايل افسانه کيست
# [BOB][BOM]يا رب آن شاهوش ماه رخ زهره جبين
# [BOM]در يکتای که و گوهر يک دانه کيست
# [BOB][BOM]گفتم آه از دل ديوانه حافظ بی تو
# [BOM]زير لب خنده زنان گفت که ديوانه کيست
# [BOB][BOM]ماهم اين هفته برون رفت و به چشمم ساليست
# [BOM]حال هجران تو چه دانی که چه مشکل حاليست
# [BOB][BOM]مردم ديده ز لطف رخ او در رخ او
# [BOM]عکس خود ديد گمان برد که مشکين خاليست
# [BOB][BOM]می‌چکد شير هنوز از لب همچون شکرش
# [BOM]گر چه در شيوه گری هر مژه‌اش قتاليست
# [BOB][BOM]ای که انگشت نمايی به کرم در همه شهر
# [BOM]وه که در کار غريبان عجبت اهماليست
# [BOB][BOM]بعد از اينم نبود شابه در جوهر فرد
# [BOM]که دهان تو در اين نکته خوش استدلاليست
# [BOB][BOM]مژده دادند که بر ما گذری خواهی کرد
# [BOM]نيت خير مگردان که مبارک فاليست
# [BOB][BOM]کوه اندوه فراقت به چه حالت بکشد
# [BOM]حافظ خسته که از ناله تنش چون ناليست
# [BOB][BOM]کس نيست که افتاده آن زلف دوتا نيست
# [BOM]در رهگذر کيست که دامی ز بلا نيست
# [BOB][BOM]چون چشم تو دل می‌برد از گوشه نشينان
# [BOM]همراه تو بودن گنه از جانب ما نيست
# [BOB][BOM]روی تو مگر آينه لطف الهيست
# [BOM]حقا که چنين است و در اين روی و ريا نيست
# [BOB][BOM]نرگس طلبد شيوه چشم تو زهی چشم
# [BOM]مسکين خبرش از سر و در ديده حيا نيست
# [BOB][BOM]از بهر خدا زلف مپيرای که ما را
# [BOM]شب نيست که صد عربده با باد صبا نيست
# [BOB][BOM]بازآی که بی روی تو ای شمع دل افروز
# [BOM]در بزم حريفان اثر نور و صفا نيست
# [BOB][BOM]تيمار غريبان اثر ذکر جميل است
# [BOM]جانا مگر اين قاعده در شهر شما نيست
# [BOB][BOM]دی می‌شد و گفتم صنما عهد به جای آر
# [BOM]گفتا غلطی خواجه در اين عهد وفا نيست
# [BOB][BOM]گر پير مغان مرشد من شد چه تفاوت
# [BOM]در هيچ سری نيست که سری ز خدا نيست
# [BOB][BOM]عاشق چه کند گر نکشد بار ملامت
# [BOM]با هيچ دلاور سپر تير قضا نيست
# [BOB][BOM]در صومعه زاهد و در خلوت صوفی
# [BOM]جز گوشه ابروی تو محراب دعا نيست
# [BOB][BOM]ای چنگ فروبرده به خون دل حافظ
# [BOM]فکرت مگر از غيرت قرآن و خدا نيست
# [BOB][BOM]مردم ديده ما جز به رخت ناظر نيست
# [BOM]دل سرگشته ما غير تو را ذاکر نيست
# [BOB][BOM]اشکم احرام طواف حرمت می‌بندد
# [BOM]گر چه از خون دل ريش دمی طاهر نيست
# [BOB][BOM]بسته دام و قفس باد چو مرغ وحشی
# [BOM]طاير سدره اگر در طلبت طاير نيست
# [BOB][BOM]عاشق مفلس اگر قلب دلش کرد نثار
# [BOM]مکنش عيب که بر نقد روان قادر نيست
# [BOB][BOM]عاقبت دست بدان سرو بلندش برسد
# [BOM]هر که را در طلبت همت او قاصر نيست
# [BOB][BOM]از روان بخشی عيسی نزنم دم هرگز
# [BOM]زان که در روح فزايی چو لبت ماهر نيست
# [BOB][BOM]من که در آتش سودای تو آهی نزنم
# [BOM]کی توان گفت که بر داغ دلم صابر نيست
# [BOB][BOM]روز اول که سر زلف تو ديدم گفتم
# [BOM]که پريشانی اين سلسله را آخر نيست
# [BOB][BOM]سر پيوند تو تنها نه دل حافظ راست
# [BOM]کيست آن کش سر پيوند تو در خاطر نيست
# ...
# [BOB][BOM]می‌روی و مژگانت خون خلق می‌ريزد
# [BOM]تيز می‌روی جانا ترسمت فرومانی
# [BOB][BOM]دل ز ناوک چشمت گوش داشتم ليکن
# [BOM]ابروی کماندارت می‌برد به پيشانی
# [BOB][BOM]جمع کن به احسانی حافظ پريشان را
# [BOM]ای شکنج گيسويت مجمع پريشانی
# [BOB][BOM]گر تو فارغی از ما ای نگار سنگين دل
# [BOM]حال خود بخواهم گفت پيش آصف ثانی
# [BOB][BOM]هواخواه توام جانا و می‌دانم که می‌دانی
# [BOM]که هم ناديده می‌بينی و هم ننوشته می‌خوانی
# [BOB][BOM]ملامتگو چه دريابد ميان عاشق و معشوق
# [BOM]نبيند چشم نابينا خصوص اسرار پنهانی
# [BOB][BOM]بيفشان زلف و صوفی را به پابازی و رقص آور
# [BOM]که از هر رقعه دلقش هزاران بت بيفشانی
# [BOB][BOM]گشاد کار مشتاقان در آن ابروی دلبند است
# [BOM]خدا را يک نفس بنشين گره بگشا ز پيشانی
# [BOB][BOM]ملک در سجده آدم زمين بوس تو نيت کرد
# [BOM]که در حسن تو لطفی ديد بيش از حد انسانی
# [BOB][BOM]چراغ افروز چشم ما نسيم زلف جانان است
# [BOM]مباد اين جمع را يا رب غم از باد پريشانی
# [BOB][BOM]دريغا عيش شبگيری که در خواب سحر بگذشت
# [BOM]ندانی قدر وقت ای دل مگر وقتی که درمانی
# [BOB][BOM]ملول از همرهان بودن طريق کاردانی نيست
# [BOM]بکش دشواری منزل به ياد عهد آسانی
# [BOB][BOM]خيال چنبر زلفش فريبت می‌دهد حافظ
# [BOM]نگر تا حلقه اقبال ناممکن نجنبانی
# [BOB][BOM]گفتند خلايق که تويی يوسف ثانی
# [BOM]چون نيک بديدم به حقيقت به از آنی
# [BOB][BOM]شيرينتر از آنی به شکرخنده که گويم
# [BOM]ای خسرو خوبان که تو شيرين زمانی
# [BOB][BOM]تشبيه دهانت نتوان کرد به غنچه
# [BOM]هرگز نبود غنچه بدين تنگ دهانی
# [BOB][BOM]صد بار بگفتی که دهم زان دهنت کام
# [BOM]چون سوسن آزاده چرا جمله زبانی
# [BOB][BOM]گويی بدهم کامت و جانت بستانم
# [BOM]ترسم ندهی کامم و جانم بستانی
# [BOB][BOM]چشم تو خدنگ از سپر جان گذراند
# [BOM]بيمار که ديده‌ست بدين سخت کمانی
# [BOB][BOM]چون اشک بيندازيش از ديده مردم
# [BOM]آن را که دمی از نظر خويش برانی
# [BOB][BOM]نسيم صبح سعادت بدان نشان که تو دانی
# [BOM]گذر به کوی فلان کن در آن زمان که تو دانی
# [BOB][BOM]تو پيک خلوت رازی و ديده بر سر راهت
# [BOM]به مردمی نه به فرمان چنان بران که تو دانی
# [BOB][BOM]بگو که جان عزيزم ز دست رفت خدا را
# [BOM]ز لعل روح فزايش ببخش آن که تو دانی
# [BOB][BOM]من اين حروف نوشتم چنان که غير ندانست
# [BOM]تو هم ز روی کرامت چنان بخوان که تو دانی
# [BOB][BOM]خيال تيغ تو با ما حديث تشنه و آب است
# [BOM]اسير خويش گرفتی بکش چنان که تو دانی
# [BOB][BOM]اميد در کمر زرکشت چگونه ببندم
# [BOM]دقيقه‌ايست نگارا در آن ميان که تو دانی
# [BOB][BOM]يکيست ترکی و تازی در اين معامله حافظ
# [BOM]حديث عشق بيان کن بدان زبان که تو دانی
# [BOB][BOM]دو يار زيرک و از باده کهن دومنی
# [BOM]فراغتی و کتابی و گوشه چمنی
# [BOB][BOM]من اين مقام به دنيا و آخرت ندهم
# [BOM]اگر چه در پی ام افتند هر دم انجمنی
# [BOB][BOM]هر آن که کنج قناعت به گنج دنيا داد
# [BOM]فروخت يوسف مصری به کمترين ثمنی
# [BOB][BOM]بيا که رونق اين کارخانه کم نشود
# [BOM]به زهد همچو تويی يا به فسق همچو منی
# [BOB][BOM]ز تندباد حوادث نمی‌توان ديدن
# [BOM]در اين چمن که گلی بوده است يا سمنی
# [BOB][BOM]ببين در آينه جام نقش بندی غيب
# [BOM]که کس به ياد ندارد چنين عجب زمنی
# [BOB][BOM]از اين سموم که بر طرف بوستان بگذشت
# [BOM]عجب که بوی گلی هست و رنگ نسترنی
# [BOB][BOM]به صبر کوش تو ای دل که حق رها نکند
# [BOM]چنين عزيز نگينی به دست اهرمنی
# [BOB][BOM]مزاج دهر تبه شد در اين بلا حافظ
# [BOM]کجاست فکر حکيمی و رای برهمنی
# [BOB][BOM]نوش کن جام شراب يک منی
# [BOM]تا بدان بيخ غم از دل برکنی
# [BOB][BOM]دل گشاده دار چون جام شراب
# [BOM]سر گرفته چند چون خم دنی
# [BOB][BOM]چون ز جام بيخودی رطلی کشی
# [BOM]کم زنی از خويشتن لاف منی
# [BOB][BOM]سنگسان شو در قدم نی همچو آب
# [BOM]جمله رنگ آميزی و تردامنی
# [BOB][BOM]دل به می دربند تا مردانه وار
# [BOM]گردن سالوس و تقوا بشکنی
# [BOB][BOM]خيز و جهدی کن چو حافظ تا مگر
# [BOM]خويشتن در پای معشوق افکنی
# [BOB][BOM]صبح است و ژاله می‌چکد از ابر بهمنی
# [BOM]برگ صبوح ساز و بده جام يک منی
# [BOB][BOM]در بحر مايی و منی افتاده‌ام بيار
# [BOM]می تا خلاص بخشدم از مايی و منی
# [BOB][BOM]خون پياله خور که حلال است خون او
# [BOM]در کار يار باش که کاريست کردنی
# [BOB][BOM]ساقی به دست باش که غم در کمين ماست
# [BOM]مطرب نگاه دار همين ره که می‌زنی
# [BOB][BOM]می ده که سر به گوش من آورد چنگ و گفت
# [BOM]خوش بگذران و بشنو از اين پير منحنی
# [BOB][BOM]ساقی به بی‌نيازی رندان که می بده
# [BOM]تا بشنوی ز صوت مغنی هوالغنی
# [BOB][BOM]ای که در کشتن ما هيچ مدارا نکنی
# [BOM]سود و سرمايه بسوزی و محابا نکنی
# [BOB][BOM]دردمندان بلا زهر هلاهل دارند
# [BOM]قصد اين قوم خطا باشد هان تا نکنی
# [BOB][BOM]رنج ما را که توان برد به يک گوشه چشم
# [BOM]شرط انصاف نباشد که مداوا نکنی
# [BOB][BOM]ديده ما چو به اميد تو درياست چرا
# [BOM]به تفرج گذری بر لب دريا نکنی
# [BOB][BOM]نقل هر جور که از خلق کريمت کردند
# [BOM]قول صاحب غرضان است تو آن‌ها نکنی
# [BOB][BOM]بر تو گر جلوه کند شاهد ما ای زاهد
# [BOM]از خدا جز می و معشوق تمنا نکنی
# [BOB][BOM]حافظا سجده به ابروی چو محرابش بر
# [BOM]که دعايی ز سر صدق جز آن جا نکنی
# [BOB][BOM]بشنو اين نکته که خود را ز غم آزاده کنی
# [BOM]خون خوری گر طلب روزی ننهاده کنی
# [BOB][BOM]آخرالامر گل کوزه گران خواهی شد
# [BOM]حاليا فکر سبو کن که پر از باده کنی
# [BOB][BOM]گر از آن آدميانی که بهشتت هوس است
# [BOM]عيش با آدمی ای چند پری زاده کنی
# [BOB][BOM]تکيه بر جای بزرگان نتوان زد به گزاف
# [BOM]مگر اسباب بزرگی همه آماده کنی
# [BOB][BOM]اجرها باشدت ای خسرو شيرين دهنان
# [BOM]گر نگاهی سوی فرهاد دل افتاده کنی
# [BOB][BOM]خاطرت کی رقم فيض پذيرد هيهات
# [BOM]مگر از نقش پراگنده ورق ساده کنی
# [BOB][BOM]کار خود گر به کرم بازگذاری حافظ
# [BOM]ای بسا عيش که با بخت خداداده کنی
# [BOB][BOM]ای صبا بندگی خواجه جلال الدين کن
# [BOM]که جهان پرسمن و سوسن آزاده کنی
# [BOB][BOM]ای دل به کوی عشق گذاری نمی‌کنی
# [BOM]اسباب جمع داری و کاری نمی‌کنی
# [BOB][BOM]چوگان حکم در کف و گويی نمی‌زنی
# [BOM]باز ظفر به دست و شکاری نمی‌کنی
# [BOB][BOM]اين خون که موج می‌زند اندر جگر تو را
# [BOM]در کار رنگ و بوی نگاری نمی‌کنی
# [BOB][BOM]مشکين از آن نشد دم خلقت که چون صبا
# [BOM]بر خاک کوی دوست گذاری نمی‌کنی
# [BOB][BOM]ترسم کز اين چمن نبری آستين گل
# [BOM]کز گلشنش تحمل خاری نمی‌کنی
# [BOB][BOM]در آستين جان تو صد نافه مدرج است
# [BOM]وان را فدای طره ياری نمی‌کنی
# [BOB][BOM]ساغر لطيف و دلکش و می افکنی به خاک
# [BOM]و انديشه از بلای خماری نمی‌کنی
# [BOB][BOM]حافظ برو که بندگی پادشاه وقت
# [BOM]گر جمله می‌کنند تو باری نمی‌کنی
# [BOB][BOM]سحرگه ره روی در سرزمينی
# [BOM]همی‌گفت اين معما با قرينی
# [BOB][BOM]که ای صوفی شراب آن گه شود صاف
# [BOM]که در شيشه برآرد اربعينی
# [BOB][BOM]خدا زان خرقه بيزار است صد بار
# [BOM]که صد بت باشدش در آستينی
# [BOB][BOM]مروت گر چه نامی بی‌نشان است
# [BOM]نيازی عرضه کن بر نازنينی
# [BOB][BOM]ثوابت باشد ای دارای خرمن
# [BOM]اگر رحمی کنی بر خوشه چينی
# [BOB][BOM]نمی‌بينم نشاط عيش در کس
# [BOM]نه درمان دلی نه درد دينی
# [BOB][BOM]درون‌ها تيره شد باشد که از غيب
# [BOM]چراغی برکند خلوت نشينی
# [BOB][BOM]گر انگشت سليمانی نباشد
# [BOM]چه خاصيت دهد نقش نگينی
# [BOB][BOM]اگر چه رسم خوبان تندخوييست
# [BOM]چه باشد گر بسازد با غمينی
# [BOB][BOM]ره ميخانه بنما تا بپرسم
# [BOM]مال خويش را از پيش بينی
# [BOB][BOM]نه حافظ را حضور درس خلوت
# [BOM]نه دانشمند را علم اليقينی
# [BOB][BOM]تو مگر بر لب آبی به هوس بنشينی
# [BOM]ور نه هر فتنه که بينی همه از خود بينی
# [BOB][BOM]به خدايی که تويی بنده بگزيده او
# [BOM]که بر اين چاکر ديرينه کسی نگزينی
# [BOB][BOM]گر امانت به سلامت ببرم باکی نيست
# [BOM]بی دلی سهل بود گر نبود بی‌دينی
# [BOB][BOM]ادب و شرم تو را خسرو مه رويان کرد
# [BOM]آفرين بر تو که شايسته صد چندينی
# [BOB][BOM]عجب از لطف تو ای گل که نشستی با خار
# [BOM]ظاهرا مصلحت وقت در آن می‌بينی
# [BOB][BOM]صبر بر جور رقيبت چه کنم گر نکنم
# [BOM]عاشقان را نبود چاره بجز مسکينی
# [BOB][BOM]باد صبحی به هوايت ز گلستان برخاست
# [BOM]که تو خوشتر ز گل و تازه‌تر از نسرينی
# [BOB][BOM]شيشه بازی سرشکم نگری از چپ و راست
# [BOM]گر بر اين منظر بينش نفسی بنشينی
# [BOB][BOM]سخنی بی‌غرض از بنده مخلص بشنو
# [BOM]ای که منظور بزرگان حقيقت بينی
# [BOB][BOM]نازنينی چو تو پاکيزه دل و پاک نهاد
# [BOM]بهتر آن است که با مردم بد ننشينی
# [BOB][BOM]سيل اين اشک روان صبر و دل حافظ برد
# [BOM]بلغ الطاقه يا مقله عينی بينی
# [BOB][BOM]تو بدين نازکی و سرکشی ای شمع چگل
# [BOM]لايق بندگی خواجه جلال الدينی
# [BOB][BOM]ساقيا سايه ابر است و بهار و لب جوی
# [BOM]من نگويم چه کن ار اهل دلی خود تو بگوی
# [BOB][BOM]بوی يک رنگی از اين نقش نمی‌آيد خيز
# [BOM]دلق آلوده صوفی به می ناب بشوی
# [BOB][BOM]سفله طبع است جهان بر کرمش تکيه مکن
# [BOM]ای جهان ديده ثبات قدم از سفله مجوی
# [BOB][BOM]دو نصيحت کنمت بشنو و صد گنج ببر
# [BOM]از در عيش درآ و به ره عيب مپوی
# [BOB][BOM]شکر آن را که دگربار رسيدی به بهار
# [BOM]بيخ نيکی بنشان و ره تحقيق بجوی
# [BOB][BOM]روی جانان طلبی آينه را قابل ساز
# [BOM]ور نه هرگز گل و نسرين ندمد ز آهن و روی
# [BOB][BOM]گوش بگشای که بلبل به فغان می‌گويد
# [BOM]خواجه تقصير مفرما گل توفيق ببوی
# [BOB][BOM]گفتی از حافظ ما بوی ريا می‌آيد
# [BOM]آفرين بر نفست باد که خوش بردی بوی
# [BOB][BOM]بلبل ز شاخ سرو به گلبانگ پهلوی
# [BOM]می‌خواند دوش درس مقامات معنوی
# [BOB][BOM]يعنی بيا که آتش موسی نمود گل
# [BOM]تا از درخت نکته توحيد بشنوی
# [BOB][BOM]مرغان باغ قافيه سنجند و بذله گوی
# [BOM]تا خواجه می خورد به غزل‌های پهلوی
# [BOB][BOM]جمشيد جز حکايت جام از جهان نبرد
# [BOM]زنهار دل مبند بر اسباب دنيوی
# [BOB][BOM]اين قصه عجب شنو از بخت واژگون
# [BOM]ما را بکشت يار به انفاس عيسوی
# [BOB][BOM]خوش وقت بوريا و گدايی و خواب امن
# [BOM]کاين عيش نيست درخور اورنگ خسروی
# [BOB][BOM]چشمت به غمزه خانه مردم خراب کرد
# [BOM]مخموريت مباد که خوش مست می‌روی
# [BOB][BOM]دهقان سالخورده چه خوش گفت با پسر
# [BOM]کای نور چشم من بجز از کشته ندروی
# [BOB][BOM]ساقی مگر وظيفه حافظ زياده داد
# [BOM]کشفته گشت طره دستار مولوی
# [BOB][BOM]ای بی‌خبر بکوش که صاحب خبر شوی
# [BOM]تا راهرو نباشی کی راهبر شوی
# [BOB][BOM]در مکتب حقايق پيش اديب عشق
# [BOM]هان ای پسر بکوش که روزی پدر شوی
# [BOB][BOM]دست از مس وجود چو مردان ره بشوی
# [BOM]تا کيميای عشق بيابی و زر شوی
# [BOB][BOM]خواب و خورت ز مرتبه خويش دور کرد
# [BOM]آن گه رسی به خويش که بی خواب و خور شوی
# [BOB][BOM]گر نور عشق حق به دل و جانت اوفتد
# [BOM]بالله کز آفتاب فلک خوبتر شوی
# [BOB][BOM]يک دم غريق بحر خدا شو گمان مبر
# [BOM]کز آب هفت بحر به يک موی تر شوی
# [BOB][BOM]از پای تا سرت همه نور خدا شود
# [BOM]در راه ذوالجلال چو بی پا و سر شوی
# [BOB][BOM]وجه خدا اگر شودت منظر نظر
# [BOM]زين پس شکی نماند که صاحب نظر شوی
# [BOB][BOM]بنياد هستی تو چو زير و زبر شود
# [BOM]در دل مدار هيچ که زير و زبر شوی
# [BOB][BOM]گر در سرت هوای وصال است حافظا
# [BOM]بايد که خاک درگه اهل هنر شوی
# [BOB][BOM]سحرم هاتف ميخانه به دولتخواهی
# [BOM]گفت بازآی که ديرينه اين درگاهی
# [BOB][BOM]همچو جم جرعه ما کش که ز سر دو جهان
# [BOM]پرتو جام جهان بين دهدت آگاهی
# [BOB][BOM]بر در ميکده رندان قلندر باشند
# [BOM]که ستانند و دهند افسر شاهنشاهی
# [BOB][BOM]خشت زير سر و بر تارک هفت اختر پای
# [BOM]دست قدرت نگر و منصب صاحب جاهی
# [BOB][BOM]سر ما و در ميخانه که طرف بامش
# [BOM]به فلک بر شد و ديوار بدين کوتاهی
# [BOB][BOM]قطع اين مرحله بی همرهی خضر مکن
# [BOM]ظلمات است بترس از خطر گمراهی
# [BOB][BOM]اگرت سلطنت فقر ببخشند ای دل
# [BOM]کمترين ملک تو از ماه بود تا ماهی
# [BOB][BOM]تو دم فقر ندانی زدن از دست مده
# [BOM]مسند خواجگی و مجلس تورانشاهی
# [BOB][BOM]حافظ خام طمع شرمی از اين قصه بدار
# [BOM]عملت چيست که فردوس برين می‌خواهی
# [BOB][BOM]ای در رخ تو پيدا انوار پادشاهی
# [BOM]در فکرت تو پنهان صد حکمت الهی
# [BOB][BOM]کلک تو بارک الله بر ملک و دين گشاده
# [BOM]صد چشمه آب حيوان از قطره سياهی
# [BOB][BOM]بر اهرمن نتابد انوار اسم اعظم
# [BOM]ملک آن توست و خاتم فرمای هر چه خواهی
# [BOB][BOM]در حکمت سليمان هر کس که شک نمايد
# [BOM]بر عقل و دانش او خندند مرغ و ماهی
# [BOB][BOM]باز ار چه گاه گاهی بر سر نهد کلاهی
# [BOM]مرغان قاف دانند آيين پادشاهی
# [BOB][BOM]تيغی که آسمانش از فيض خود دهد آب
# [BOM]تنها جهان بگيرد بی منت سپاهی
# [BOB][BOM]کلک تو خوش نويسد در شان يار و اغيار
# [BOM]تعويذ جان فزايی افسون عمر کاهی
# [BOB][BOM]ای عنصر تو مخلوق از کيميای عزت
# [BOM]و ای دولت تو ايمن از وصمت تباهی
# [BOB][BOM]ساقی بيار آبی از چشمه خرابات
# [BOM]تا خرقه‌ها بشوييم از عجب خانقاهی
# [BOB][BOM]عمريست پادشاها کز می تهيست جامم
# [BOM]اينک ز بنده دعوی و از محتسب گواهی
# [BOB][BOM]گر پرتوی ز تيغت بر کان و معدن افتد
# [BOM]ياقوت سرخ رو را بخشند رنگ کاهی
# [BOB][BOM]دانم دلت ببخشد بر عجز شب نشينان
# [BOM]گر حال بنده پرسی از باد صبحگاهی
# [BOB][BOM]جايی که برق عصيان بر آدم صفی زد
# [BOM]ما را چگونه زيبد دعوی بی‌گناهی
# [BOB][BOM]حافظ چو پادشاهت گه گاه می‌برد نام
# [BOM]رنجش ز بخت منما بازآ به عذرخواهی
# [BOB][BOM]در همه دير مغان نيست چو من شيدايی
# [BOM]خرقه جايی گرو باده و دفتر جايی
# [BOB][BOM]دل که آيينه شاهيست غباری دارد
# [BOM]از خدا می‌طلبم صحبت روشن رايی
# [BOB][BOM]کرده‌ام توبه به دست صنم باده فروش
# [BOM]که دگر می نخورم بی رخ بزم آرايی
# [BOB][BOM]نرگس ار لاف زد از شيوه چشم تو مرنج
# [BOM]نروند اهل نظر از پی نابينايی
# [BOB][BOM]شرح اين قصه مگر شمع برآرد به زبان
# [BOM]ور نه پروانه ندارد به سخن پروايی
# [BOB][BOM]جوی‌ها بسته‌ام از ديده به دامان که مگر
# [BOM]در کنارم بنشانند سهی بالايی
# [BOB][BOM]کشتی باده بياور که مرا بی رخ دوست
# [BOM]گشت هر گوشه چشم از غم دل دريايی
# [BOB][BOM]سخن غير مگو با من معشوقه پرست
# [BOM]کز وی و جام می‌ام نيست به کس پروايی
# [BOB][BOM]اين حديثم چه خوش آمد که سحرگه می‌گفت
# [BOM]بر در ميکده‌ای با دف و نی ترسايی
# [BOB][BOM]گر مسلمانی از اين است که حافظ دارد
# [BOM]آه اگر از پی امروز بود فردايی
# [BOB][BOM]به چشم کرده‌ام ابروی ماه سيمايی
# [BOM]خيال سبزخطی نقش بسته‌ام جايی
# [BOB][BOM]اميد هست که منشور عشقبازی من
# [BOM]از آن کمانچه ابرو رسد به طغرايی
# [BOB][BOM]سرم ز دست بشد چشم از انتظار بسوخت
# [BOM]در آرزوی سر و چشم مجلس آرايی
# [BOB][BOM]مکدر است دل آتش به خرقه خواهم زد
# [BOM]بيا ببين که که را می‌کند تماشايی
# [BOB][BOM]به روز واقعه تابوت ما ز سرو کنيد
# [BOM]که می‌رويم به داغ بلندبالايی
# [BOB][BOM]زمام دل به کسی داده‌ام من درويش
# [BOM]که نيستش به کس از تاج و تخت پروايی
# [BOB][BOM]در آن مقام که خوبان ز غمزه تيغ زنند
# [BOM]عجب مدار سری اوفتاده در پايی
# [BOB][BOM]مرا که از رخ او ماه در شبستان است
# [BOM]کجا بود به فروغ ستاره پروايی
# [BOB][BOM]فراق و وصل چه باشد رضای دوست طلب
# [BOM]که حيف باشد از او غير او تمنايی
# [BOB][BOM]درر ز شوق برآرند ماهيان به نثار
# [BOM]اگر سفينه حافظ رسد به دريايی
# [BOB][BOM]سلامی چو بوی خوش آشنايی
# [BOM]بدان مردم ديده روشنايی
# [BOB][BOM]درودی چو نور دل پارسايان
# [BOM]بدان شمع خلوتگه پارسايی
# [BOB][BOM]نمی‌بينم از همدمان هيچ بر جای
# [BOM]دلم خون شد از غصه ساقی کجايی
# [BOB][BOM]ز کوی مغان رخ مگردان که آن جا
# [BOM]فروشند مفتاح مشکل گشايی
# [BOB][BOM]عروس جهان گر چه در حد حسن است
# [BOM]ز حد می‌برد شيوه بی‌وفايی
# [BOB][BOM]دل خسته من گرش همتی هست
# [BOM]نخواهد ز سنگين دلان موميايی
# [BOB][BOM]می صوفی افکن کجا می‌فروشند
# [BOM]که در تابم از دست زهد ريايی
# [BOB][BOM]رفيقان چنان عهد صحبت شکستند
# [BOM]که گويی نبوده‌ست خود آشنايی
# [BOB][BOM]مرا گر تو بگذاری ای نفس طامع
# [BOM]بسی پادشايی کنم در گدايی
# [BOB][BOM]بياموزمت کيميای سعادت
# [BOM]ز همصحبت بد جدايی جدايی
# [BOB][BOM]مکن حافظ از جور دوران شکايت
# [BOM]چه دانی تو ای بنده کار خدايی
# [BOB][BOM]ای پادشه خوبان داد از غم تنهايی
# [BOM]دل بی تو به جان آمد وقت است که بازآيی
# [BOB][BOM]دايم گل اين بستان شاداب نمی‌ماند
# [BOM]درياب ضعيفان را در وقت توانايی
# [BOB][BOM]ديشب گله زلفش با باد همی‌کردم
# [BOM]گفتا غلطی بگذر زين فکرت سودايی
# [BOB][BOM]صد باد صبا اين جا با سلسله می‌رقصند
# [BOM]اين است حريف ای دل تا باد نپيمايی
# [BOB][BOM]مشتاقی و مهجوری دور از تو چنانم کرد
# [BOM]کز دست بخواهد شد پاياب شکيبايی
# [BOB][BOM]يا رب به که شايد گفت اين نکته که در عالم
# [BOM]رخساره به کس ننمود آن شاهد هرجايی
# [BOB][BOM]ساقی چمن گل را بی روی تو رنگی نيست
# [BOM]شمشاد خرامان کن تا باغ بيارايی
# [BOB][BOM]ای درد توام درمان در بستر ناکامی
# [BOM]و ای ياد توام مونس در گوشه تنهايی
# [BOB][BOM]در دايره قسمت ما نقطه تسليميم
# [BOM]لطف آن چه تو انديشی حکم آن چه تو فرمايی
# [BOB][BOM]فکر خود و رای خود در عالم رندی نيست
# [BOM]کفر است در اين مذهب خودبينی و خودرايی
# [BOB][BOM]زين دايره مينا خونين جگرم می ده
# [BOM]تا حل کنم اين مشکل در ساغر مينايی
# [BOB][BOM]حافظ شب هجران شد بوی خوش وصل آمد
# [BOM]شاديت مبارک باد ای عاشق شيدايی
# [BOB][BOM]ای دل گر از آن چاه زنخدان به درآيی
# [BOM]هر جا که روی زود پشيمان به درآيی
# [BOB][BOM]هش دار که گر وسوسه عقل کنی گوش
# [BOM]آدم صفت از روضه رضوان به درآيی
# [BOB][BOM]شايد که به آبی فلکت دست نگيرد
# [BOM]گر تشنه لب از چشمه حيوان به درآيی
# [BOB][BOM]جان می‌دهم از حسرت ديدار تو چون صبح
# [BOM]باشد که چو خورشيد درخشان به درآيی
# [BOB][BOM]چندان چو صبا بر تو گمارم دم همت
# [BOM]کز غنچه چو گل خرم و خندان به درآيی
# [BOB][BOM]در تيره شب هجر تو جانم به لب آمد
# [BOM]وقت است که همچون مه تابان به درآيی
# [BOB][BOM]بر رهگذرت بسته‌ام از ديده دو صد جوی
# [BOM]تا بو که تو چون سرو خرامان به درآيی
# [BOB][BOM]حافظ مکن انديشه که آن يوسف مه رو
# [BOM]بازآيد و از کلبه احزان به درآيی
# [BOB][BOM]می خواه و گل افشان کن از دهر چه می‌جويی
# [BOM]اين گفت سحرگه گل بلبل تو چه می‌گويی
# [BOB][BOM]مسند به گلستان بر تا شاهد و ساقی را
# [BOM]لب گيری و رخ بوسی می نوشی و گل بويی
# [BOB][BOM]شمشاد خرامان کن و آهنگ گلستان کن
# [BOM]تا سرو بياموزد از قد تو دلجويی
# [BOB][BOM]تا غنچه خندانت دولت به که خواهد داد
# [BOM]ای شاخ گل رعنا از بهر که می‌رويی
# [BOB][BOM]امروز که بازارت پرجوش خريدار است
# [BOM]درياب و بنه گنجی از مايه نيکويی
# [BOB][BOM]چون شمع نکورويی در رهگذر باد است
# [BOM]طرف هنری بربند از شمع نکورويی
# [BOB][BOM]آن طره که هر جعدش صد نافه چين ارزد
# [BOM]خوش بودی اگر بودی بوييش ز خوش خويی
# [BOB][BOM]هر مرغ به دستانی در گلشن شاه آمد
# [BOM]بلبل به نواسازی حافظ به غزل گويی[EOS]

# %%
import numpy as np
cls_token = '[CLS]'
bob_token = '[BOB]'
bom_token = '[BOM]'
eos_token = '[EOS]'
def load_and_tokenize(filename): #TODO
    with open(filename, 'r', encoding='utf-8') as f:
        text = f.readlines()[2:]
        is_beit = True
        poem_str = f'\n{cls_token}'
        for index , line in enumerate(text):
            if line.strip() == '':
                continue
            poem_str += f"{bob_token + bom_token if is_beit else bom_token}{line}"
            is_beit = not is_beit
    poem_str += f'{eos_token}'
    text = poem_str.strip()
    tokens = tokenizer.encode(text)
    return torch.tensor(tokens, dtype=torch.long)

class DataLoaderLite:
    def __init__(self, B, T, process_rank, num_processes, files):
        self.B = B
        self.T = T
        self.process_rank = process_rank
        self.num_processes = num_processes
        self.files = files
        assert len(files) > 0, f"no txt files provided"

        self.reset()

    def reset(self):
        self.current_file = 0
        self.tokens = load_and_tokenize(self.files[self.current_file])
        self.current_position = self.B * self.T * self.process_rank

    def next_batch(self):
        B, T = self.B, self.T
        buf = self.tokens[self.current_position : self.current_position+B*T+1]
        x = (buf[:-1]).view(B, T) # inputs
        y = (buf[1:]).view(B, T) # targets
        # advance the position in the tensor
        self.current_position += B * T * self.num_processes
#         # if loading the next batch would be out of bounds, advance to next shard
        if self.current_position + (B * T * self.num_processes + 1) > len(self.tokens): #TODO
            # self.current_file = (self.current_file + 1) % len(self.files)
            # self.tokens = load_and_tokenize(self.files[self.current_file], self.tokenizer)
            # self.current_position = B * T * self.process_rank
            self.reset()
        return x, y


# -----------------------------------------------------------------------------
# helper function for HellaSwag eval
# takes tokens, mask, and logits, returns the index of the completion with the lowest loss

def get_most_likely_row(tokens, mask, logits):
    # evaluate the autoregressive loss at all positions
    shift_logits = (logits[..., :-1, :]).contiguous()
    shift_tokens = (tokens[..., 1:]).contiguous()
    flat_shift_logits = shift_logits.view(-1, shift_logits.size(-1))
    flat_shift_tokens = shift_tokens.view(-1)
    shift_losses = F.cross_entropy(flat_shift_logits, flat_shift_tokens, reduction='none')
    shift_losses = shift_losses.view(tokens.size(0), -1)
    # now get the average loss just for the completion region (where mask == 1), in each row
    shift_mask = (mask[..., 1:]).contiguous() # we must shift mask, so we start at the last prompt token
    masked_shift_losses = shift_losses * shift_mask
    # sum and divide by the number of 1s in the mask
    sum_loss = masked_shift_losses.sum(dim=1)
    avg_loss = sum_loss / shift_mask.sum(dim=1)
    # now we have a loss for each of the 4 completions
    # the one with the lowest loss should be the most likely
    pred_norm = avg_loss.argmin().item()
    return pred_norm

# %%
def generate_poem(model, device, device_type, ddp_rank, phrase):
    result = 'result.txt'
    model.eval()
    num_return_sequences = 4
    max_length = 32
    tokens = enc.encode(phrase)
    tokens = torch.tensor(tokens, dtype=torch.long)
    tokens = tokens.unsqueeze(0).repeat(num_return_sequences, 1)
    xgen = tokens.to(device)
    sample_rng = torch.Generator(device=device)
    sample_rng.manual_seed(42 + ddp_rank)
    generated_poems = []  # List to store generated poems

    while xgen.size(1) < max_length:
        # forward the model to get the logits
        with torch.no_grad():
            with torch.autocast(device_type=device_type, dtype=torch.bfloat16):
                logits, loss = model(xgen) # (B, T, vocab_size)
            # take the logits at the last position
            logits = logits[:, -1, :] # (B, vocab_size)
            # get the probabilities
            probs = F.softmax(logits, dim=-1)
            # do top-k sampling of 50 (huggingface pipeline default)
            # topk_probs here becomes (5, 50), topk_indices is (5, 50)
            topk_probs, topk_indices = torch.topk(probs, 50, dim=-1) # return top k high probability
            # select a token from the top-k probabilities
            # note: multinomial does not demand the input to sum to 1
            ix = torch.multinomial(topk_probs, 1, generator=sample_rng) # (B, 1)
            # gather the corresponding indices
            xcol = torch.gather(topk_indices, -1, ix) # (B, 1)
            # append to the sequence
            xgen = torch.cat((xgen, xcol), dim=1)

    # collect and save the generated text
    for i in range(num_return_sequences):
        tokens = xgen[i, :max_length].tolist()
        decoded = enc.decode(tokens)
        print(f"rank {ddp_rank} sample {i}: {decoded}")
        generated_poems.append(decoded)

    # print the generated text
    for i in range(num_return_sequences):
        tokens = xgen[i, :max_length].tolist() #TODO edit print and remove special tokens test. tokenizer.special_tokens = false
        decoded = enc.decode(tokens)
        print(f"rank {ddp_rank} sample {i}: {decoded}")
        torch.save(model.state_dict(), data_root + '/saved_model.pth')
        output_file = data_root + "/" + result

        with open(output_file, "a") as out_f:
            out_f.write(f"sample {i}: {decoded}\n")
    return generated_poems  # Return the list of generated poems

# %%
def generate_poem(model, device, device_type, ddp_rank, phrase):
    result = 'result.txt'
    model.eval()
    num_return_sequences = 4
    max_length = 32
    tokens = enc.encode(phrase)
    tokens = torch.tensor(tokens, dtype=torch.long)
    tokens = tokens.unsqueeze(0).repeat(num_return_sequences, 1)
    xgen = tokens.to(device)
    sample_rng = torch.Generator(device=device)
    sample_rng.manual_seed(42 + ddp_rank)

    generated_poems = []  # List to store generated poems

    while xgen.size(1) < max_length:
        # forward the model to get the logits
        with torch.no_grad():
            with torch.autocast(device_type=device_type, dtype=torch.bfloat16):
                logits, loss = model(xgen) # (B, T, vocab_size)
            # take the logits at the last position
            logits = logits[:, -1, :] # (B, vocab_size)
            # get the probabilities
            probs = F.softmax(logits, dim=-1)
            # do top-k sampling of 50 (huggingface pipeline default)
            topk_probs, topk_indices = torch.topk(probs, 50, dim=-1) # return top k high probability
            # select a token from the top-k probabilities
            ix = torch.multinomial(topk_probs, 1, generator=sample_rng) # (B, 1)
            # gather the corresponding indices
            xcol = torch.gather(topk_indices, -1, ix) # (B, 1)
            # append to the sequence
            xgen = torch.cat((xgen, xcol), dim=1)

    # collect and save the generated text
    for i in range(num_return_sequences):
        tokens = xgen[i, :max_length].tolist()
        decoded = enc.decode(tokens)
        print(f"rank {ddp_rank} sample {i}: {decoded}")
        generated_poems.append(decoded)

    # Save the model state (optional)
    torch.save(model.state_dict(), data_root + '/saved_model.pth')

    # Save the generated poems to a file
    output_file = data_root + "/" + result
    with open(output_file, "a") as out_f:
        for i, poem in enumerate(generated_poems):
            out_f.write(f"sample {i}: {poem}\n")

    return generated_poems  # Return the list of generated poems

# %%
print("RANK:", os.environ.get('RANK', 'Not set'))
print("LOCAL_RANK:", os.environ.get('LOCAL_RANK', 'Not set'))
print("WORLD_SIZE:", os.environ.get('WORLD_SIZE', 'Not set'))
# Out:
# RANK: Not set
# LOCAL_RANK: Not set
# WORLD_SIZE: Not set

# %%
from torch.distributed import init_process_group, destroy_process_group
from torch.nn.parallel import DistributedDataParallel as DDP
import torch.distributed as dist

# set up DDP (distributed data parallel).
# torchrun command sets the env variables RANK, LOCAL_RANK, and WORLD_SIZE
ddp = int(os.environ.get('RANK', -1)) != -1 # is this a ddp run?
print(ddp, "DDP")
if ddp:
    # use of DDP atm demands CUDA, we set the device appropriately according to rank
    assert torch.cuda.is_available(), "for now i think we need CUDA for DDP"
    init_process_group(backend='nccl')
    ddp_rank = int(os.environ['RANK'])
    ddp_local_rank = int(os.environ['LOCAL_RANK'])
    ddp_world_size = int(os.environ['WORLD_SIZE'])
    device = f'cuda:{ddp_local_rank}'
    torch.cuda.set_device(device)
    master_process = ddp_rank == 0 # this process will do logging, checkpointing etc.
else:
    # vanilla, non-DDP run
    ddp_rank = 0
    ddp_local_rank = 0
    ddp_world_size = 1
    master_process = True
    # attempt to autodetect device
    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda"
    elif hasattr(torch.backends, "mps") and torch.backends.mps.is_available():
        device = "mps"
    print(f"using device: {device}")

# added after video, pytorch can be serious about it's device vs. device_type distinction
device_type = "cuda" if device.startswith("cuda") else "cpu"

torch.manual_seed(1337)
if torch.cuda.is_available():
    torch.cuda.manual_seed(1337)

# enc = tiktoken.get_encoding("gpt2")

total_batch_size = 8192 #524288 # 2**19, ~0.5M, in number of tokens
B = 8 # micro batch size
T = 1024 # sequence length
assert total_batch_size % (B * T * ddp_world_size) == 0, "make sure total_batch_size is divisible by B * T * ddp_world_size"
grad_accum_steps = total_batch_size // (B * T * ddp_world_size)
if master_process:
    print(f"total desired batch size: {total_batch_size}")
    print(f"=> calculated gradient accumulation steps: {grad_accum_steps}")

# tokenizer = AutoTokenizer.from_pretrained("bolbolzaban/gpt2-persian")


import random

# all_files = [os.path.join(data_root, f) for f in os.listdir(data_root) if f.endswith('.txt')]
# random.shuffle(all_files)  # Shuffle to ensure random split

# split_index = int(0.9 * len(all_files))  # 90% for training, 10% for validation
# train_files = all_files[:split_index]
# val_files = all_files[split_index:]

# train_loader = DataLoaderLite(B=B, T=T, process_rank=ddp_rank, num_processes=ddp_world_size, files=train_files)
# val_loader = DataLoaderLite(B=B, T=T, process_rank=ddp_rank, num_processes=ddp_world_size, files=val_files)
# new method



# Initialize an empty list for all lines
all_lines = []

with open(data_root + "/input/" + poems_file_name, 'r', encoding='utf-8') as f:
    lines = f.readlines()
    all_lines.extend(lines)  # Add lines from the current file to all_lines

# Shuffle lines to ensure randomness
random.shuffle(all_lines)

# Split the lines into training and validation sets
split_index = int(0.9 * len(all_lines))  # 90% for training, 10% for validation
train_lines = all_lines[:split_index]
val_lines = all_lines[split_index:]
with open(os.path.join(data_root, 'train.txt'), 'w', encoding='utf-8') as train_file:
    train_file.writelines(train_lines)

with open(os.path.join(data_root, 'val.txt'), 'w', encoding='utf-8') as val_file:
    val_file.writelines(val_lines)

train_file_path = os.path.join(data_root, 'train.txt')
val_file_path = os.path.join(data_root, 'val.txt')
print(train_file_path)
print(val_file_path)
train_loader = DataLoaderLite(B=B, T=T, process_rank=ddp_rank, num_processes=ddp_world_size, files=[train_file_path])
val_loader = DataLoaderLite(B=B, T=T, process_rank=ddp_rank, num_processes=ddp_world_size, files=[val_file_path])

print("data is ready....")


torch.set_float32_matmul_precision('high') # this  is for gpu tunning

# create model
model = GPT(GPTConfig(vocab_size=50304))
# model = GPT.from_pretrained("gpt2") # or init from OpenAI GPT-2
model.to(device)
use_compile = False # torch.compile interferes with HellaSwag eval and Generation. TODO fix
if use_compile:
    model = torch.compile(model)
if ddp:
    model = DDP(model, device_ids=[ddp_local_rank])
raw_model = model.module if ddp else model # always contains the "raw" unwrapped model

max_lr = 6e-4
min_lr = max_lr * 0.1
warmup_steps = 700
max_steps = 19073 # 19,073 steps is ~1 epoch, if data is 10B tokens and batch size 0.5M tokens
def get_lr(it):
    # 1) linear warmup for warmup_iters steps
    if it < warmup_steps:
        return max_lr * (it+1) / warmup_steps
    # 2) if it > lr_decay_iters, return min learning rate
    if it > max_steps:
        return min_lr
    # 3) in between, use cosine decay down to min learning rate
    decay_ratio = (it - warmup_steps) / (max_steps - warmup_steps)
    assert 0 <= decay_ratio <= 1
    coeff = 0.5 * (1.0 + math.cos(math.pi * decay_ratio)) # coeff starts at 1 and goes to 0
    return min_lr + coeff * (max_lr - min_lr)

# optimize!
optimizer = raw_model.configure_optimizers(weight_decay=0.1, learning_rate=6e-4, device_type=device_type)

# create the log directory we will write checkpoints to and log to
log_dir = data_root + "/log"
os.makedirs(log_dir, exist_ok=True)
log_file = os.path.join(log_dir, f"log.txt")
with open(log_file, "w") as f: # open for writing to clear the file
    pass
output_file = data_root + "/output.txt"
for step in range(max_steps):
    t0 = time.time()
    last_step = (step == max_steps - 1)

    # once in a while evaluate our validation loss
    if step % 250 == 0 or last_step:
        model.eval() # we want to use model. we dont want to train it.
        val_loader.reset()
        with torch.no_grad():
            val_loss_accum = 0.0
            val_loss_steps = 20
            for _ in range(val_loss_steps):
                x, y = val_loader.next_batch()
                x, y = x.to(device), y.to(device)
                with torch.autocast(device_type=device_type, dtype=torch.bfloat16): # do something with ram to make it efficient and sp
                    logits, loss = model(x, y)
                loss = loss / val_loss_steps
                val_loss_accum += loss.detach()
        if ddp:
            dist.all_reduce(val_loss_accum, op=dist.ReduceOp.AVG)
        if master_process:
            print(f"validation loss: {val_loss_accum.item():.4f}")
            with open(log_file, "a") as f:
                f.write(f"{step} val {val_loss_accum.item():.4f}\n")
            if step > 0 and (step % 5000 == 0 or last_step):
                # optionally write model checkpoints
                checkpoint_path = os.path.join(log_dir, f"model_{step:05d}.pt")
                checkpoint = {
                    'model': raw_model.state_dict(),
                    'config': raw_model.config,
                    'step': step,
                    'val_loss': val_loss_accum.item()
                }
                # you might also want to add optimizer.state_dict() and
                # rng seeds etc., if you wanted to more exactly resume training
                torch.save(checkpoint, checkpoint_path)

    # once in a while evaluate hellaswag
    # if (step % 250 == 0 or last_step) and (not use_compile):
    #     num_correct_norm = 0
    #     num_total = 0 # ToDo i commented the following for loop since it relates to Hellasweg
    #     # for i, example in enumerate(iterate_examples("val")):
    #     #     # only process examples where i % ddp_world_size == ddp_rank
    #     #     if i % ddp_world_size != ddp_rank:
    #     #         continue
    #     #     # render the example into tokens and labels
    #     #     _, tokens, mask, label = render_example(example)
    #     #     tokens = tokens.to(device)
    #     #     mask = mask.to(device)
    #     #     # get the logits
    #     #     with torch.no_grad():
    #     #         with torch.autocast(device_type=device_type, dtype=torch.bfloat16):
    #     #             logits, loss = model(tokens)
    #     #         pred_norm = get_most_likely_row(tokens, mask, logits)
    #     #     num_total += 1
    #     #     num_correct_norm += int(pred_norm == label)
    #     # reduce the stats across all processes
    #     if ddp:
    #         num_total = torch.tensor(num_total, dtype=torch.long, device=device)
    #         num_correct_norm = torch.tensor(num_correct_norm, dtype=torch.long, device=device)
    #         dist.all_reduce(num_total, op=dist.ReduceOp.SUM)
    #         dist.all_reduce(num_correct_norm, op=dist.ReduceOp.SUM)
    #         num_total = num_total.item()
    #         print('num_total', num_total)
    #         num_correct_norm = num_correct_norm.item()
    #         print('num_correct_norm', num_correct_norm)
    #     print("ddp not available")
    #     acc_norm = num_correct_norm / num_total #if num_total != 0 else 0
    #     if master_process:
    #         print(f"Dataset accuracy: {num_correct_norm}/{num_total}={acc_norm:.4f}")
    #         with open(log_file, "a") as f:
    #             f.write(f"{step} hella {acc_norm:.4f}\n")

    # once in a while generate from the model (except step 0, which is noise)
    if ((step > 0 and step % 250 == 0) or last_step) and (not use_compile):
        phrase = "دردم از یار است و درمان نیز هم"
        generate_poem(model, device, device_type, ddp_rank, phrase)
    # do one step of the optimization
    print("start training the model")
    model.train()
    optimizer.zero_grad()
    loss_accum = 0.0
    for micro_step in range(grad_accum_steps):
        print(f"step {micro_step} of training")
        x, y = train_loader.next_batch()
        x, y = x.to(device), y.to(device)
        # added after video, this field is also used by the forward pass.
        if ddp:
            model.require_backward_grad_sync = (micro_step == grad_accum_steps - 1)
        with torch.autocast(device_type=device_type, dtype=torch.bfloat16):
            logits, loss = model(x, y)
        # we have to scale the loss to account for gradient accumulation,
        # because the gradients just add on each successive backward().
        # addition of gradients corresponds to a SUM in the objective, but
        # instead of a SUM we want MEAN. Scale the loss here so it comes out right
        loss = loss / grad_accum_steps
        loss_accum += loss.detach()
        loss.backward()
    if ddp:
        dist.all_reduce(loss_accum, op=dist.ReduceOp.AVG)
    norm = torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
    # determine and set the learning rate for this iteration
    lr = get_lr(step)
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr
    optimizer.step()
    if device_type == "cuda":
        torch.cuda.synchronize() # wait for the GPU to finish work
    t1 = time.time()
    dt = t1 - t0 # time difference in seconds
    tokens_processed = train_loader.B * train_loader.T * grad_accum_steps * ddp_world_size
    tokens_per_sec = tokens_processed / dt
    if master_process:
        print(f"step {step:5d} | loss: {loss_accum.item():.6f} | lr {lr:.4e} | norm: {norm:.4f} | dt: {dt*1000:.2f}ms | tok/sec: {tokens_per_sec:.2f}")
        with open(log_file, "a") as f:
            f.write(f"{step} train {loss_accum.item():.6f}\n")

if ddp:
    destroy_process_group()
# Out:
# False DDP
# using device: cuda
# total desired batch size: 8192
# => calculated gradient accumulation steps: 1
# /content/drive/MyDrive/nano_gpt/train.txt
# /content/drive/MyDrive/nano_gpt/val.txt
# data is ready....
# num decayed parameter tensors: 26, with 30,326,784 parameters
# num non-decayed parameter tensors: 50, with 30,720 parameters
# using fused AdamW: True
# validation loss: 10.9556
# start training the model
# step 0 of training
# step     0 | loss: 10.951500 | lr 8.5714e-07 | norm: 9.6144 | dt: 6098.91ms | tok/sec: 1343.19
# start training the model
# step 0 of training
# step     1 | loss: 10.939346 | lr 1.7143e-06 | norm: 9.5394 | dt: 744.07ms | tok/sec: 11009.76
# start training the model
# step 0 of training
# step     2 | loss: 10.920486 | lr 2.5714e-06 | norm: 9.7699 | dt: 741.02ms | tok/sec: 11054.98
# start training the model
# step 0 of training
# step     3 | loss: 10.874313 | lr 3.4286e-06 | norm: 9.6087 | dt: 744.13ms | tok/sec: 11008.84
# start training the model
# step 0 of training
# step     4 | loss: 10.831238 | lr 4.2857e-06 | norm: 9.6635 | dt: 740.57ms | tok/sec: 11061.72
# start training the model
# step 0 of training
# step     5 | loss: 10.770180 | lr 5.1429e-06 | norm: 9.4938 | dt: 748.66ms | tok/sec: 10942.23
# start training the model
# step 0 of training
# step     6 | loss: 10.704536 | lr 6.0000e-06 | norm: 9.0570 | dt: 740.12ms | tok/sec: 11068.44
# start training the model
# step 0 of training
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-c18c8c809151> in <cell line: 139>()
#     244     optimizer.step()
#     245     if device_type == "cuda":
# --> 246         torch.cuda.synchronize() # wait for the GPU to finish work
#     247     t1 = time.time()
#     248     dt = t1 - t0 # time difference in seconds
#
# /usr/local/lib/python3.10/dist-packages/torch/cuda/__init__.py in synchronize(device)
#     790     _lazy_init()
#     791     with torch.cuda.device(device):
# --> 792         return torch._C._cuda_synchronize()
#     793
#     794
#
# KeyboardInterrupt:

# %%
#Loading the Model:
# from GPT import MyModel   # Replace with your model class definition
# model = MyModel()
model.load_state_dict(torch.load(data_root + '/saved_model.pth'))  #replacewith model path
phrase = "توانا بود هرکه دانا بود"
generated_poems=generate_poem(model, device, device_type, ddp_rank, phrase)

result_file_path = data_root + '/result.txt'
with open(result_file_path, 'w', encoding='utf-8') as f:
    for poem in generated_poems:
        f.write(poem + '\n')

print(f"Generated poems saved to {result_file_path}")


# Flatten the special tokens into a list
tokens_to_remove = [special_tokens["cls_token"], special_tokens["eos_token"]] + special_tokens["additional_special_tokens"]
#TODO

# Function to remove special tokens from a line
def remove_special_tokens(line):
    for token in tokens_to_remove:
        line = line.replace(token, "")
    return line

# Open the input file for reading and the output file for writing
input_file_path = data_root + "/result.txt"  # Change this to your input file path
output_file_path = data_root + '/' + 'final_output.txt'  # Change this to your desired output file path

with open(input_file_path, 'r', encoding='utf-8') as infile, open(output_file_path, 'w', encoding='utf-8') as outfile:
    for line in infile:
        # Remove special tokens from the current line
        cleaned_line = remove_special_tokens(line)
        # Write the cleaned line to the output file
        print(cleaned_line)
        outfile.write(cleaned_line)

print("Special tokens removed and output saved to", output_file_path)
# Out:
# rank 0 sample 0: [CLS] توانا بود هرکه دانا بود[SEP] زلف‌دهد[BOB][BOM] من در در جان با دل هر درب کن و ه<unk>ار <unk>ن<unk>نه
# rank 0 sample 1: [CLS] توانا بود هرکه دانا بود[SEP] دوست[BOM] چشم <unk>چ و خاک م همه حافظ[BOB][BOM] سر سر و آن ب<unk>ز<unk>ن<unk>نه
# rank 0 sample 2: [CLS] توانا بود هرکه دانا بود[SEP] است[BOM] می‌زنم ای خاک چشم ب<unk>ن دل از در ا<unk>ه<unk>ن<unk>ن<unk>ق<unk>
# rank 0 sample 3: [CLS] توانا بود هرکه دانا بود[SEP] به خاک خود تو ن<unk>ان تو کرد[BOM] تا گل ما می‌ان[BOM] آن نظر ب<unk>مت<unk>
# Generated poems saved to /content/drive/MyDrive/nano_gpt/result.txt
#  توانا بود هرکه دانا بود زلف‌دهد من در در جان با دل هر درب کن و هار ننه
#
#  توانا بود هرکه دانا بود دوست چشم چ و خاک م همه حافظ سر سر و آن بزننه
#
#  توانا بود هرکه دانا بود است می‌زنم ای خاک چشم بن دل از در اهننق
#
#  توانا بود هرکه دانا بود به خاک خود تو نان تو کرد تا گل ما می‌ان آن نظر بمت
#
# Special tokens removed and output saved to /content/drive/MyDrive/nano_gpt/final_output.txt
